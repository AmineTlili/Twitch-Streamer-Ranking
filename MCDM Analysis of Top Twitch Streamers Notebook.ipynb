# %% [markdown]
# # Multi-Criteria Decision Analysis of Top Twitch Streamers

# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ### I- Data Cleaning

# %%
df = pd.read_csv("twitchdata.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Channel               1000 non-null   object
#  1   Watch time(Minutes)   1000 non-null   int64
#  2   Stream time(minutes)  1000 non-null   int64
#  3   Peak viewers          1000 non-null   int64
#  4   Average viewers       1000 non-null   int64
#  5   Followers             1000 non-null   int64
#  6   Followers gained      1000 non-null   int64
#  7   Views gained          1000 non-null   int64
#  8   Partnered             1000 non-null   bool
#  9   Mature                1000 non-null   bool
#  10  Language              1000 non-null   object
# dtypes: bool(2), int64(7), object(2)
# memory usage: 72.4+ KB

# %% [markdown]
# #### Filtering Mature Streamers
#
# To focus on streamers with mature content, we filter the dataset where the **Mature** column is `True`.
# This helps in analyzing content that may have different audience engagement patterns compared to general streaming channels.
#
# ##### Selecting the Top 200 Streamers by Followers
#
# After filtering for mature content, we select the **top 200 streamers** based on the number of **Followers**.
# This ensures that we analyze the most influential mature streamers with the largest audience reach.

# %%
df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  Average viewers  Followers  Followers gained  Views gained  Partnered  Mature    Language
# 0     xQcOW           6196161750                215250        222720            27716    3246298           1734810      93036735       True   False     English
# 1  summit1g           6091677300                211845        310998            25610    5310163           1370184      89705964       True   False     English
# 2    Gaules           5644590915                515280        387315            10976    1767635           1023779     102611607       True    True  Portuguese
# 3  ESL_CSGO           3970318140                517740        300575             7714    3944850            703986     106546942       True   False     English
# 4      Tfue           3671000070                123660        285644            29602    8938903           2068424      78998587       True   False     English

# %%
mature_streamers = df[df["Mature"] == True]
top_mature_streamers = mature_streamers.nlargest(200, "Followers")

# %%
top_mature_streamers.head()
# Out:
#             Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  Average viewers  Followers  Followers gained  Views gained  Partnered  Mature Language
# 10     TimTheTatman           2834436990                108780        142067            25664    5265659           1244341      50119786       True    True  English
# 15   MontanaBlack88           2408460990                 67740        181600            33514    2911316           1101093      37189666       True    True   German
# 16       sodapoppin           2329440420                115305        107833            19659    2786162            236169      39334821       True    True  English
# 74         Symfuhny           1076179485                137400         45671             7327    2355063            704327      18756705       True    True  English
# 167            wtcN            582125625                 77385         73861             7438    1852272            566210      25333548       True    True  Turkish

# %% [markdown]
# #### Selection of Criteria for STREAMER Ranking
#
# For ranking TV shows logically, the **7 best criteria** to use for decision-making are:
#
# 1. **Followers gained** – Represents the popularity growth of the show.
# 2. **Views gained** – Indicates how much attention the show received.
# 3. **Peak viewers** – Shows the maximum number of viewers at once (indicates viral moments).
# 4. **Average viewers** – Represents consistent engagement over time.
# 5. **Watch time (Minutes)** – Measures total audience consumption (engagement metric).
# 6. **Stream time (Minutes)** – Helps understand how long the content was available.
# 7. **Partnered** (Boolean: 1 for Yes, 0 for No) – Partnership status can indicate official recognition and influence.

# %%
criteria = [
    "Followers gained", "Views gained", "Peak viewers",
    "Average viewers", "Watch time(Minutes)", "Stream time(minutes)", "Partnered"
]

# %%
df_final = top_mature_streamers[["Channel"] + criteria]

# %%
df_final
# Out:
#                        Channel  Followers gained  Views gained  Peak viewers  Average viewers  Watch time(Minutes)  Stream time(minutes)  Partnered
# 10                TimTheTatman           1244341      50119786        142067            25664           2834436990                108780       True
# 15              MontanaBlack88           1101093      37189666        181600            33514           2408460990                 67740       True
# 16                  sodapoppin            236169      39334821        107833            19659           2329440420                115305       True
# 74                    Symfuhny            704327      18756705         45671             7327           1076179485                137400       True
# 167                       wtcN            566210      25333548         73861             7438            582125625                 77385       True
# 2                       Gaules           1023779     102611607        387315            10976           5644590915                515280       True
# 218                      Aydan            425036      11009240         51268             3507            495563580                140595       True
# 77                    Rainbow6            428942      16786627        135471            11535           1031011170                 82380       True
# 301                    Trick2g            115863       8688676         28917             2650            371417130                132945       True
# 779                      Dyrus               111       3724340         11338             1123            158999070                138300       True
# 244                   Nadeshot            428800       7844647         40327             7985            440331540                 50175       True
# 176            KendineMuzisyen            486410      17629667         43422             9583            567374295                 58545       True
# 638               SovietWomble            214775       5846971          9616             2900            187497450                 63360       True
# 71                      forsen            164792      18534278         33966            10080           1106781045                109140       True
# 179                  Greekgodx            403108      12441822         45741             7083            561616335                 89745       True
# 24               TheRealKnossi           1082039      25342894        288459            24595           1811696100                 56010       True
# 988           CallMeCarsonLIVE            732108       3533199         61531             8208            123486240                 14340       True
# 273                  A_Seagull             55228       7374161         28779             4193            407156655                 95160       True
# 296                    Grimmmz             37734       7803917         21993             2153            377312595                176580       True
# 468                   Rammus53            332303      11041262         16370             2217            247730100                104520       True
# 184                    Nick28T             78054       6777975         15155             3024            556741020                183660       True
# 793                Sweet_Anita            510063       7927278         21594             2690            155731920                 57600       True
# 927  Call of Duty (callofduty)             50321       5423366        170131            19897            130938960                  3645       True
# 32                    MOONMOON             95776      13505898         24892            11220           1527882945                124680       True
# 353                    ELoTRiX            318247       5587147         31194             5620            319051995                 56310       True
# 84                     ZeratoR            240442      31456198        262273            10516           1011013035                 84960       True
# 816                   Stewie2K            289867       5771575         27416             5296            151271895                 24735       True
# 119                       aceu            763489      15894732         26141             6328            744620970                118125       True
# 212                 AustinShow            378656      11648873         72199            24739            509643945                 21000       True
# 821                Frankkaster            356711       5878239         49127             4886            150181140                 30975       True
# 760                   Cryaotic             24644       2326058          7169             1727            162138405                 85785       True
# 568             ElcanaldeJoaco            758797       4893535         48072             8673            208060515                 20445       True
# 774                      dizzy            122263       4572893         19262             2997            159505395                 49125       True
# 653                      Pengu            241309       5240516          7707             2452            182358345                 70665       True
# 45                    Sardoche            370358      32261961        144066             8066           1361024835                164235       True
# 623                       zEkO            370683       5338943         21313             4440            193867860                 44970       True
# 711                   Pimpeano            665323       3744461         38592             6469            170116395                 21420       True
# 786            ProfessorBroman             22714       3579571         12676              955            157325925                154635       True
# 339                     scoped            728892       8279834         47343             5165            330160515                 63360       True
# 826                RobertoCein            422842       2907888         15249             1270            149162865                114120       True
# 80               Trainwreckstv            379973      12449595         49379             7134           1021699920                148425       True
# 171                Reborn_Live            682512       9965787         57849            17488            578122875                 32100       True
# 89              AdmiralBulldog             66513      17095676         16681             6198            972317520                154845       True
# 126                   DreadzTV             57448      32228705         35865             6249            715644660                109725       True
# 508                    GTimeTV            155419       5838039         14110             1022            232140015                187335       True
# 231                INSCOPE21TV            491663      10630158         51244             7554            468467130                 59925       True
# 489                    Arteezy             99726       3776042         31009            19681            240834885                 12285       True
# 526                  Skadoodle            219104       5373229         30357             2318            225401640                 89955       True
# 323                   singsing             45761       6526670         11839             2735            346171920                126795       True
# 138                    Destiny            115692       8579344         24101             3894            650910525                162690       True
# 361               ALOHADANCETV             92209      12461610         18317             4288            312898725                 70320       True
# 63                      Quin69             87860      19512632         36742             6616           1186941750                174270       True
# 901                  innocents            279080       3488587         13654             1557            135250410                 83790       True
# 249                   HoneyMad             74407      14755893         21369             6394            434971635                 67995       True
# 660                      Datto             89739       4566171         82047             2122            181075290                 71400       True
# 810                    natalan            462674       2737155          9561             2240            152469705                 60510       True
# 910               RayNarvaezJr             29068       2180691          6611             1589            133649520                 82605       True
# 182                 Diegosaurs            270255       9851921         32463             4150            558587535                128580       True
# 114                     TeePee            238257      17102146         78741             4410            789698115                170010       True
# 524                      Mendo            176007       5487693         25321             1959            226473345                 99480       True
# 211                      B0aty             49577       8448691         22375             3152            510323715                151215       True
# 859                  MANvsGAME              2336       2713787          5831             2103            142696875                 65775       True
# 226                   mistermv            150486      12959273         39961             6627            476597370                 71655       True
# 873                AnniTheDuck            263210       7336341          7894             2533            140975745                 53220       True
# 137            老皮 (mobilmobil)             34362      20520762         16497             5303            652685055                126120       True
# 197                  Vinesauce             80616       5560969         19065             6125            536989080                 86790       True
# 752                     goncho            236558       6156791         18091             2431            162817050                 61770       True
# 842             PainLivestream             81619       2283772         15002             1635            145610160                 89775       True
# 848                     trihex             29678       5777172         21721             1157            144608640                121515       True
# 345                      sips_             84034       4331397          7872             2984            325731015                108990       True
# 70                       Vader             57681      11535871         16289             5913           1110952500                184305       True
# 140                     RATIRL            249048      14109245         14480             4420            649761570                145050       True
# 116                   Agraelus            132125      20334558         23555             4642            779867430                169515       True
# 416                  AlphaCast            152951       8864009         28898             3046            281533785                 84165       True
# 573                 WeAreTheVR             85526       9512134         20851             2688            206446935                 75975       True
# 820                     Herdyn             91098       5639711          4254             1180            150266550                123060       True
# 783                  Kandyland            202294      11207571          9203             1748            157882170                 86745       True
# 55                       Gorgc            136943      20882507         56449             8683           1252711830                141135       True
# 374                   tarzaned            172683       7744943         14602             4159            306010080                 72390       True
# 42                    ROSHTEIN            242369      17836875         45843            11717           1435735725                118995      False
# 606                  Peereira7            361206       6222094         14532             1377            198252765                133800       True
# 295                   Homyatol            249186       6981248         26274             4826            378734925                 70725       True
# 744                    LobosJr             27173       3970888         12709             1332            163736505                121335       True
# 466                   1DrakoNz            252999       6950267         15242             2655            249476295                 99180       True
# 453                   KabajiOW             87338       4098475         13865             3252            254772135                 72240       True
# 298                  boyMinORu             73551      17822170         22141             2717            376358805                142830       True
# 307                   ANGRYPUG             48331       4962556          9822             1892            360278835                184845       True
# 480                      MoMaN            120693       8390437         16550             1363            244502235                145755       True
# 867                   EFEUYGAC            297215       5234400         14481             3700            141455130                 38910       True
# 942               FantaBobShow             86339       3598696          8248             1936            128845890                 65565       True
# 368          AvoidingThePuddle             67040       4202354         13108             3893            309117315                 80955       True
# 434                   Jerma985             92752       3411872         15921             4773            269372580                 57495       True
# 985                   Surefour             46991       2066041          7911             2289            124056555                 53145       True
# 688                     Maghla            234216       6831650         16695             2124            175236000                 77505       True
# 592                      mang0             53694       3077795         24391             1403            202842615                140325       True
# 230                 melharucos             59167      17845821         13825             3519            468792120                130275       True
# 315                Distortion2             44982       5500067         11495             1953            354144315                170220       True
# 914                 mandiocaa1             29691       2567198          9540             4355            132533775                 29685       True
# 495                      maxim            129119       5439874         21262             3173            236707830                 71685       True
# 889                    JonBams             75728       1940922          5577             1522            139067415                 88830       True
# 729                      BreaK             18289       3880016          9531             1432            167534355                115560       True
# 548                   Heelmike            208795       3406743         18963             2115            216316170                101400       True
# 674                    WARDELL            288200       5304936         16215             1394            178718460                127155       True
# 65                    dasMEHDI             76568       7422911         47683             5013           1172969025                231465       True
# 274                       koil             50231       7743238         13421             2791            403848390                145035       True
# 679                     Tyceno            250536       1623230         40407             4015            177947595                 42825       True
# 911                   Tanovich            219383       3677360         10352             1434            133079115                 89865       True
# 381                       Kiwo             38195       4900030         10836             1243            299469345                234330       True
# 382                     adolfz            154653       2743587         15928             4926            299235990                 62520       True
# 190                김도 (kimdoe)             10062      14188002         11759             4062            549244755                134985       True
# 839                     Tourva            182413       7888629          5067             1185            146412075                116070       True
# 742              Vargskelethor             60041       2147906          6577             2809            164759730                 58395       True
# 559                     Criken             32753       3593487         11050             1828            212449905                113040       True
# 538                  ItsSlikeR            154360       5243404         12762             2317            218576850                 95655       True
# 624                   x6FlipiN            186655       6462906         19304             2712            193573740                 61095       True
# 300                 BurkeBlack             13471       5367772          4922             2154            372767025                171675       True
# 940            西門夜說 (westdoor)             16908       5018006          5363             1165            128928105                109065       True
# 731                     Xposed            147449       2220313          8580             1475            167309220                111240       True
# 648                 SheriffEli             11832       2355559          5988             1291            185394810                143400       True
# 555                    BikeMan             11101       3531376          7223             1486            214504440                136845       True
# 993          LAGTVMaximusBlack             13251       2310313          7138              725            123125340                161535       True
# 551           OfficialAndyPyro             29422      10284627          9676             1027            215726910                209625       True
# 366                    Overpow             29344       9020762         10858             2004            309892665                153015       True
# 512               GrandPOObear             44926       3877237         13295             2230            231011760                101175       True
# 481                     Kotton             80920       4459178         58818             2757            244412715                 73005       True
# 484                   pijack11            144993       6752832          8181             1569            243578730                148140       True
# 254                   Sequisha             86220       7404102         19755             2540            426325350                163530       True
# 716                      THump            115028       2168664          8063             1885            169365870                 92055       True
# 245                     buddha             24901       6326808         11971             3184            438460680                135090       True
# 796                   cellinrj            122045       3621969          7136             1711            154982550                 87945       True
# 769                   Tanxlive             40087       7067999          6899              971            159875505                161010       True
# 861                 foggedftw2            109500       3438208          8622             1220            142444290                111675       True
# 329                       NymN            111122       4409296         23488             3402            340095510                100125       True
# 589                      iLame             66490       9831952          4911             1243            203117655                161025       True
# 807                    DieHahn             44782       3418935          8048             1229            152767545                125025       True
# 790                      AkTep             51862       4273193          6300             1541            156236730                 94545       True
# 242                    mch_AGG            124548      11142208         11191              884            443328990                499575       True
# 387              The_Happy_Hob             38712       4158704          8560             2834            295999245                106125       True
# 831                      Limmy            136263       2433739          6575             1641            148371105                 90600       True
# 168                      Anton            128050       6176254        137531             3199            581034300                142890       True
# 331                   MinosTV_            192534       5554989         24576             2034            338084550                167190       True
# 365                 RoyalPhunk             34597       4921311         12141             2934            311093010                104565       True
# 519                   PsheroTV             59927       5384623         10739             1166            228376905                184215       True
# 909                      MuTeX            114872       1615269          9448              824            133816530                150015       True
# 897                Ezekiel_III              8969       4018240         18804             1190            136597425                109890       True
# 834                   CoconutB             62459       2691775          4596             1171            147918285                122565       True
# 216                       Kyle             60506       5692219          9339             3059            501208575                161295       True
# 458                        cyr             49771       4106827         19267             1678            252345645                146190       True
# 248                 嬌兔 (zrush)             49296      13297850         10628             3084            436243530                137910       True
# 698                  BRNWOWZK1             87295       5330221          6981              465            173484990                365670       True
# 693          Zombie_Barricades             60031       2219053          4497              735            173823135                228765       True
# 467                     Pace22            112723       3080537         10350             1524            247862850                156975       True
# 778            BananaSlamJamma             23267       2546439          5152             1263            159071145                113595       True
# 308                   MarcaoRX             65904       4541683          5210             1258            359273445                336690       True
# 735                     CrReaM              6207       1614843          8098             1150            166587645                142350       True
# 620              龜狗 (gueigotv)             25466       6005834          9918             1373            194262165                134895       True
# 404              limit_maximum             70116       5965543        124818             1886            288857850                 85905       True
# 762                 Sweatcicle            120954       2372907         14550             1023            161489220                137880       True
# 286                      Shotz             48388       5464553         10316             2523            385739280                153105       True
# 259              BarbarousKing             42931       4822422         13419             2244            419187600                188895       True
# 431                   JokerdTV            157656       9070954        319862             2013            271815660                120165       True
# 766                  Alkaizerx             21706       3152805         12430             1312            161185890                103950       True
# 419                      PENTA             40474       2786097          7172             2322            280798065                116745       True
# 801                      CaMaK              7578       3019137          9437             1759            154277370                 87375       True
# 172                CasinoDaddy             42680       7493491          6524             2168            577240710                267465      False
# 824                    H0llyLP             11875       3846703          4958             1116            149766195                130860       True
# 643                    Broeki1             25995       4702541         13091             1317            186562710                141675       True
# 280                 StaysafeTV             73218       7427189         15608             2876            399746130                135180       True
# 655                  gabepeixe             25034       2795325          5955             1788            181929585                101730       True
# 705              超負荷 (sam1268)             20433       5691145         11861             4538            171602475                 35805       True
# 813             小夜夜 (albislol)             10939       4554443          3740              706            152033250                208485       True
# 583                    Worrun_            103762       3425022         41881             1728            204440715                 94455       True
# 960                       Hype            101271       6185689         10030             1674            126704460                 81510       True
# 406                  guit88man             25130       8666012          7681             1989            287764245                140685       True
# 270                   Aurateur             26782       4368785         15547             2492            407829960                163815       True
# 751                       Vovo             92033       3786059          7268              974            162887760                150555       True
# 891                OuterHeaven              7924       1037346          6955             1101            137995935                 94575       True
# 545                      Lasqa             25351       5298356         10010             2863            216969405                 72210       True
# 849                   Spaceboy             27050       2614773         10590             1107            144599880                123015       True
# 166                 RatedEpicz             74221       7251200         11860             3336            582401145                175920       True
# 421                     uhSnow             43869       3334788          8375             3150            280296045                 88500       True
# 683                 Drjayfisto             41353       6201998          4092             1105            177159195                155340       True
# 975               TommyKayLIVE             58673       2561302          3536             1124            124680810                108105       True
# 581                  skill4ltu             46398       4548052          4049             1503            205017270                135510       True
# 727                  DougisRaw             74509       2149900         22641             1076            167875230                153960       True
# 505            theRealShooKon3             37207       2944974          6148             1333            233210205                166260       True
# 939                 Krayn_Live             20572       4621526          4183              918            129103425                137040       True
# 972                    HeyarTV             17695       2506556          2343              786            124878165                155700       True
# 145          木棉花官方頻道 (muse_tw)            120954      13670649         16702             1397            625892895                446655       True
# 882                  akagreenn            114861       3514645         21136             2902            140084580                 51600       True
# 491                     flamuu             36301       3225407          5242             1851            239018790                126915       True
# 717                    MaTaFe_            106957       4182011          8535             1096            169215480                153525       True
# 503                   CuteDog_             22074       3489772          7016             1104            234058290                207090       True
# 808                     chowh1             84231       4175567          8221              980            152754465                143415       True
# 666               GhostFreak66             89879       2471382         94791             1029            179939730                107295       True
# 369                     Ko0416             12127      11705657          5448             1515            307823730                200625       True
# 181                 ClassyBeef             88671       6626543         33624             1941            558883590                273660      False
# 673              Crocodyle_lol             77142       3657348          8810             1802            178727670                 96000       True
# 498                       WOKE            105725       3460437         50598             3827            235303170                 51600       True
# 804                  roflgator             46487       1449834         14329             1281            153963765                110910       True

# %% [markdown]
# ### II- AHP WEIGHTS

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns (if needed)
pd.set_option('display.expand_frame_repr', False)  # Prevent line wrapping

# %%
# Given AHP Pairwise Comparison Matrix
criteria_matrix = np.array([
    [1.00, 1.00, 0.50, 0.33, 0.67, 3.33, 1.00],
    [1.00, 1.00, 0.67, 0.50, 0.67, 2.00, 1.00],
    [2.00, 1.50, 1.00, 1.00, 3.00, 3.00, 1.00],
    [3.00, 2.00, 1.00, 1.00, 3.00, 3.00, 1.00],
    [1.50, 0.33, 0.33, 0.33, 1.00, 2.50, 0.50],
    [0.30, 0.50, 0.33, 0.33, 0.40, 1.00, 0.50],
    [1.00, 1.00, 1.00, 1.00, 2.00, 2.00, 1.00]
])

# Random Consistency Index (RI) values for different matrix sizes
RI = {
    1: 0.00, 2: 0.00, 3: 0.58, 4: 0.90, 5: 1.12, 6: 1.24, 7: 1.32,
    8: 1.41, 9: 1.45, 10: 1.49, 11: 1.51, 12: 1.48, 13: 1.56, 14: 1.57, 15: 1.59
}

# Step 1: Normalize the pairwise comparison matrix
column_sums = criteria_matrix.sum(axis=0)
normalized_matrix = criteria_matrix / column_sums

# Step 2: Compute the AHP weights (average of normalized values per row)
criteria_weights = normalized_matrix.mean(axis=1)

# Step 3: Compute the AW Matrix (Multiply original matrix by weight vector)
AW = criteria_matrix.dot(criteria_weights)

# Step 4: Compute Lambda Max (λ_max) as the average of AW / criteria_weights
lambda_max = np.mean(AW / criteria_weights)

# Step 5: Compute Consistency Index (CI)
n = criteria_matrix.shape[0]  # Number of criteria
CI = (lambda_max - n) / (n - 1)

# Step 6: Compute Consistency Ratio (CR)
RI_n = RI.get(n, 1.6)  # Get RI for 'n' criteria, default to 1.6 if not found
CR = CI / RI_n

# Display results
print("\nComputed AHP Criteria Weights:")
print(np.round(criteria_weights, 3))

print(f"\nLambda Max (λ_max): {lambda_max:.4f}")
print(f"Consistency Index (CI): {CI:.4f}")
print(f"Consistency Ratio (CR): {CR:.4f}")
# Out:
# Computed AHP Criteria Weights:
# [0.12  0.119 0.209 0.233 0.095 0.06  0.163]
#
# Lambda Max (λ_max): 7.1126
# Consistency Index (CI): 0.0188
# Consistency Ratio (CR): 0.0142

# %%
# Given AHP Weights
ahp_weights = np.array([0.12, 0.119, 0.209, 0.233, 0.095, 0.06, 0.163])

# %% [markdown]
# #### 1- WSM, WPM and WASPAS

# %%
# ------------------------------------------------------------------------------
# Function Definitions
# ------------------------------------------------------------------------------
def generate_criteria_type_matrix(m):
    """Generate criteria type matrix (1 = maximization criteria)."""
    return np.ones((1, m))  # All criteria are maximization

def normalize_matrix_max(mat, criteria_types):
    """Normalize decision matrix using max normalization."""
    normalized_matrix = np.zeros_like(mat, dtype=float)
    for j in range(mat.shape[1]):
        if criteria_types[0, j] == 1:  # Maximization
            normalized_matrix[:, j] = mat[:, j] / np.max(mat[:, j])
    return normalized_matrix

def compute_wsm_score(normalized_matrix, weights):
    """Compute Weighted Sum Model (WSM) scores."""
    return np.sum(normalized_matrix * weights, axis=1)

def compute_wpm_score(normalized_matrix, weights):
    """Compute Weighted Product Model (WPM) scores."""
    return np.prod(normalized_matrix ** weights, axis=1)

def compute_wasspass_score(wsm_scores, wpm_scores, lambda_value=0.5):
    """Compute WASSPASS scores (combining WSM and WPM)."""
    return lambda_value * wsm_scores + (1 - lambda_value) * wpm_scores

# ------------------------------------------------------------------------------
# Data Processing and Ranking
# ------------------------------------------------------------------------------

# Extract decision matrix
decision_matrix = df_final[criteria].values

# Normalize the matrix using max normalization
m = decision_matrix.shape[1]
criteria_types = generate_criteria_type_matrix(m)
normalized_matrix = normalize_matrix_max(decision_matrix, criteria_types)

# Compute scores using AHP weights
wsm_scores = compute_wsm_score(normalized_matrix, ahp_weights)
wpm_scores = compute_wpm_score(normalized_matrix, ahp_weights)
wasspass_scores = compute_wasspass_score(wsm_scores, wpm_scores, lambda_value=0.5)

# Append scores to DataFrame
df_final["WSM Score"] = wsm_scores
df_final["WPM Score"] = wpm_scores
df_final["WASSPASS Score"] = wasspass_scores

# Rank alternatives for each method separately
df_wsm_ranking = df_final.sort_values(by="WSM Score", ascending=False)
df_wpm_ranking = df_final.sort_values(by="WPM Score", ascending=False)
df_wasspass_ranking = df_final.sort_values(by="WASSPASS Score", ascending=False)

# ------------------------------------------------------------------------------
# Display Results in Separate Tables
# ------------------------------------------------------------------------------
print("\nRanking Based on WSM Score:")
print(df_wsm_ranking[["Channel", "WSM Score"]])

print("\nRanking Based on WPM Score:")
print(df_wpm_ranking[["Channel", "WPM Score"]])

print("\nRanking Based on WASSPASS Score:")
print(df_wasspass_ranking[["Channel", "WASSPASS Score"]])
# Out:
# Ranking Based on WSM Score:
#                        Channel  WSM Score
# 2                       Gaules   0.821038
# 15              MontanaBlack88   0.691731
# 24               TheRealKnossi   0.660400
# 10                TimTheTatman   0.656581
# 16                  sodapoppin   0.478887
# 84                     ZeratoR   0.464212
# 212                 AustinShow   0.435001
# 45                    Sardoche   0.411978
# 927  Call of Duty (callofduty)   0.406906
# 171                Reborn_Live   0.406643
# 77                    Rainbow6   0.404075
# 431                   JokerdTV   0.393887
# 74                    Symfuhny   0.362371
# 167                       wtcN   0.357359
# 119                       aceu   0.339449
# 176            KendineMuzisyen   0.336774
# 489                    Arteezy   0.336042
# 568             ElcanaldeJoaco   0.333971
# 988           CallMeCarsonLIVE   0.331715
# 55                       Gorgc   0.328769
# 80               Trainwreckstv   0.324803
# 71                      forsen   0.320130
# 32                    MOONMOON   0.319569
# 231                INSCOPE21TV   0.317774
# 339                     scoped   0.317284
# 114                     TeePee   0.312047
# 179                  Greekgodx   0.310131
# 168                      Anton   0.305383
# 244                   Nadeshot   0.303978
# 711                   Pimpeano   0.302661
# 63                      Quin69   0.300194
# 126                   DreadzTV   0.293535
# 218                      Aydan   0.293515
# 65                    dasMEHDI   0.286268
# 116                   Agraelus   0.277171
# 226                   mistermv   0.276543
# 89              AdmiralBulldog   0.275727
# 404              limit_maximum   0.272010
# 70                       Vader   0.271998
# 145          木棉花官方頻道 (muse_tw)   0.271787
# 182                 Diegosaurs   0.271231
# 821                Frankkaster   0.270830
# 140                     RATIRL   0.269748
# 353                    ELoTRiX   0.268001
# 242                    mch_AGG   0.265750
# 137            老皮 (mobilmobil)   0.261553
# 793                Sweet_Anita   0.261064
# 249                   HoneyMad   0.258510
# 295                   Homyatol   0.257466
# 623                       zEkO   0.255807
# 816                   Stewie2K   0.254687
# 138                    Destiny   0.254083
# 197                  Vinesauce   0.249238
# 468                   Rammus53   0.248437
# 666               GhostFreak66   0.248360
# 660                      Datto   0.247337
# 679                     Tyceno   0.246743
# 298                  boyMinORu   0.244564
# 230                 melharucos   0.244387
# 606                  Peereira7   0.241381
# 810                    natalan   0.241137
# 498                       WOKE   0.241087
# 331                   MinosTV_   0.240570
# 301                    Trick2g   0.240009
# 826                RobertoCein   0.240007
# 190                김도 (kimdoe)   0.239972
# 481                     Kotton   0.239496
# 361               ALOHADANCETV   0.239494
# 273                  A_Seagull   0.239492
# 416                  AlphaCast   0.239339
# 374                   tarzaned   0.239008
# 166                 RatedEpicz   0.238446
# 184                    Nick28T   0.238345
# 867                   EFEUYGAC   0.238182
# 466                   1DrakoNz   0.237889
# 211                      B0aty   0.237763
# 526                  Skadoodle   0.237126
# 382                     adolfz   0.236254
# 254                   Sequisha   0.234437
# 248                 嬌兔 (zrush)   0.233752
# 674                    WARDELL   0.233201
# 329                       NymN   0.232539
# 308                   MarcaoRX   0.231431
# 698                  BRNWOWZK1   0.230099
# 280                 StaysafeTV   0.229560
# 752                     goncho   0.229549
# 296                    Grimmmz   0.229437
# 688                     Maghla   0.229259
# 524                      Mendo   0.229016
# 216                       Kyle   0.228960
# 434                   Jerma985   0.228904
# 624                   x6FlipiN   0.228139
# 495                      maxim   0.227624
# 548                   Heelmike   0.227471
# 873                AnniTheDuck   0.227331
# 274                       koil   0.227155
# 638               SovietWomble   0.226377
# 583                    Worrun_   0.226031
# 783                  Kandyland   0.225383
# 508                    GTimeTV   0.225198
# 653                      Pengu   0.224852
# 259              BarbarousKing   0.224625
# 573                 WeAreTheVR   0.224540
# 245                     buddha   0.224444
# 901                  innocents   0.224185
# 480                      MoMaN   0.223863
# 368          AvoidingThePuddle   0.223106
# 270                   Aurateur   0.222303
# 538                  ItsSlikeR   0.221779
# 484                   pijack11   0.221486
# 286                      Shotz   0.221431
# 323                   singsing   0.220976
# 369                     Ko0416   0.219759
# 774                      dizzy   0.219729
# 307                   ANGRYPUG   0.219457
# 345                      sips_   0.219294
# 315                Distortion2   0.219278
# 381                       Kiwo   0.219181
# 366                    Overpow   0.219116
# 453                   KabajiOW   0.218966
# 551           OfficialAndyPyro   0.218166
# 882                  akagreenn   0.218100
# 839                     Tourva   0.216692
# 911                   Tanovich   0.216681
# 705              超負荷 (sam1268)   0.216578
# 365                 RoyalPhunk   0.216405
# 467                     Pace22   0.216073
# 458                        cyr   0.215895
# 406                  guit88man   0.214671
# 300                 BurkeBlack   0.214419
# 592                      mang0   0.214417
# 589                      iLame   0.214275
# 519                   PsheroTV   0.214219
# 387              The_Happy_Hob   0.213217
# 727                  DougisRaw   0.213129
# 421                     uhSnow   0.212540
# 762                 Sweatcicle   0.211153
# 717                    MaTaFe_   0.211114
# 731                     Xposed   0.210448
# 512               GrandPOObear   0.210176
# 914                 mandiocaa1   0.209953
# 545                      Lasqa   0.208955
# 848                     trihex   0.208910
# 503                   CuteDog_   0.208690
# 960                       Hype   0.208614
# 419                      PENTA   0.208468
# 693          Zombie_Barricades   0.208462
# 716                      THump   0.207633
# 796                   cellinrj   0.207565
# 751                       Vovo   0.207232
# 769                   Tanxlive   0.206975
# 831                      Limmy   0.206967
# 643                    Broeki1   0.206817
# 909                      MuTeX   0.206498
# 808                     chowh1   0.206485
# 620              龜狗 (gueigotv)   0.206295
# 673              Crocodyle_lol   0.206149
# 861                 foggedftw2   0.206082
# 842             PainLivestream   0.205886
# 505            theRealShooKon3   0.205873
# 559                     Criken   0.205736
# 820                     Herdyn   0.205683
# 683                 Drjayfisto   0.205141
# 491                     flamuu   0.204740
# 581                  skill4ltu   0.204613
# 742              Vargskelethor   0.203932
# 786            ProfessorBroman   0.203475
# 744                    LobosJr   0.203228
# 942               FantaBobShow   0.203213
# 813             小夜夜 (albislol)   0.203098
# 897                Ezekiel_III   0.202040
# 555                    BikeMan   0.201939
# 804                  roflgator   0.201308
# 807                    DieHahn   0.201300
# 790                      AkTep   0.200709
# 729                      BreaK   0.200638
# 779                      Dyrus   0.200035
# 834                   CoconutB   0.199527
# 766                  Alkaizerx   0.199395
# 655                  gabepeixe   0.199208
# 648                 SheriffEli   0.198897
# 889                    JonBams   0.198829
# 849                   Spaceboy   0.198809
# 985                   Surefour   0.198387
# 801                      CaMaK   0.197324
# 735                     CrReaM   0.197215
# 939                 Krayn_Live   0.197113
# 824                    H0llyLP   0.196799
# 993          LAGTVMaximusBlack   0.196731
# 760                   Cryaotic   0.196667
# 940            西門夜說 (westdoor)   0.196313
# 975               TommyKayLIVE   0.196037
# 778            BananaSlamJamma   0.195662
# 910               RayNarvaezJr   0.194815
# 972                    HeyarTV   0.194574
# 859                  MANvsGAME   0.194200
# 891                OuterHeaven   0.189710
# 42                    ROSHTEIN   0.188276
# 181                 ClassyBeef   0.089146
# 172                CasinoDaddy   0.072258
#
# Ranking Based on WPM Score:
#                        Channel  WPM Score
# 2                       Gaules   0.753144
# 15              MontanaBlack88   0.608712
# 10                TimTheTatman   0.597006
# 24               TheRealKnossi   0.572362
# 16                  sodapoppin   0.415216
# 84                     ZeratoR   0.382497
# 45                    Sardoche   0.358648
# 77                    Rainbow6   0.338640
# 212                 AustinShow   0.288241
# 171                Reborn_Live   0.277614
# 167                       wtcN   0.275934
# 74                    Symfuhny   0.270274
# 55                       Gorgc   0.248532
# 176            KendineMuzisyen   0.241683
# 80               Trainwreckstv   0.241385
# 114                     TeePee   0.229821
# 71                      forsen   0.227010
# 119                       aceu   0.220211
# 231                INSCOPE21TV   0.219444
# 179                  Greekgodx   0.218921
# 32                    MOONMOON   0.204554
# 63                      Quin69   0.202082
# 431                   JokerdTV   0.200413
# 244                   Nadeshot   0.197323
# 339                     scoped   0.195115
# 218                      Aydan   0.191639
# 168                      Anton   0.189382
# 568             ElcanaldeJoaco   0.186430
# 927  Call of Duty (callofduty)   0.185835
# 126                   DreadzTV   0.185534
# 226                   mistermv   0.181723
# 65                    dasMEHDI   0.178197
# 988           CallMeCarsonLIVE   0.172934
# 116                   Agraelus   0.171658
# 182                 Diegosaurs   0.170340
# 89              AdmiralBulldog   0.156531
# 711                   Pimpeano   0.156003
# 353                    ELoTRiX   0.155942
# 140                     RATIRL   0.154204
# 489                    Arteezy   0.153903
# 821                Frankkaster   0.152032
# 295                   Homyatol   0.149193
# 70                       Vader   0.147898
# 249                   HoneyMad   0.145827
# 138                    Destiny   0.144183
# 404              limit_maximum   0.137973
# 137            老皮 (mobilmobil)   0.135220
# 816                   Stewie2K   0.131771
# 197                  Vinesauce   0.131198
# 416                  AlphaCast   0.130323
# 623                       zEkO   0.129935
# 301                    Trick2g   0.128478
# 298                  boyMinORu   0.126759
# 273                  A_Seagull   0.126710
# 498                       WOKE   0.126170
# 361               ALOHADANCETV   0.125646
# 793                Sweet_Anita   0.125512
# 481                     Kotton   0.123371
# 660                      Datto   0.122630
# 468                   Rammus53   0.121184
# 374                   tarzaned   0.121182
# 230                 melharucos   0.120725
# 526                  Skadoodle   0.119475
# 679                     Tyceno   0.118810
# 211                      B0aty   0.118543
# 145          木棉花官方頻道 (muse_tw)   0.118302
# 331                   MinosTV_   0.118232
# 329                       NymN   0.116674
# 254                   Sequisha   0.114122
# 466                   1DrakoNz   0.113763
# 184                    Nick28T   0.113564
# 495                      maxim   0.111149
# 166                 RatedEpicz   0.110797
# 382                     adolfz   0.110747
# 624                   x6FlipiN   0.108867
# 524                      Mendo   0.108712
# 280                 StaysafeTV   0.107790
# 867                   EFEUYGAC   0.107371
# 573                 WeAreTheVR   0.107308
# 752                     goncho   0.105421
# 434                   Jerma985   0.104520
# 248                 嬌兔 (zrush)   0.104321
# 688                     Maghla   0.103700
# 583                    Worrun_   0.102750
# 666               GhostFreak66   0.101665
# 296                    Grimmmz   0.101624
# 548                   Heelmike   0.100151
# 274                       koil   0.100141
# 606                  Peereira7   0.099173
# 774                      dizzy   0.098450
# 368          AvoidingThePuddle   0.097584
# 190                김도 (kimdoe)   0.096584
# 216                       Kyle   0.096040
# 638               SovietWomble   0.095983
# 674                    WARDELL   0.095933
# 538                  ItsSlikeR   0.095366
# 453                   KabajiOW   0.095020
# 882                  akagreenn   0.094940
# 480                      MoMaN   0.094704
# 242                    mch_AGG   0.093322
# 323                   singsing   0.091965
# 783                  Kandyland   0.090904
# 245                     buddha   0.090802
# 873                AnniTheDuck   0.090491
# 259              BarbarousKing   0.090010
# 653                      Pengu   0.088560
# 810                    natalan   0.088426
# 286                      Shotz   0.088322
# 826                RobertoCein   0.088226
# 270                   Aurateur   0.087845
# 345                      sips_   0.086983
# 365                 RoyalPhunk   0.085985
# 901                  innocents   0.085477
# 508                    GTimeTV   0.085425
# 458                        cyr   0.085015
# 315                Distortion2   0.084284
# 484                   pijack11   0.084190
# 366                    Overpow   0.082833
# 592                      mang0   0.081613
# 307                   ANGRYPUG   0.081197
# 705              超負荷 (sam1268)   0.080173
# 512               GrandPOObear   0.079993
# 387              The_Happy_Hob   0.078466
# 467                     Pace22   0.078021
# 421                     uhSnow   0.077897
# 911                   Tanovich   0.077576
# 960                       Hype   0.076655
# 545                      Lasqa   0.075426
# 727                  DougisRaw   0.074352
# 406                  guit88man   0.074238
# 848                     trihex   0.073394
# 519                   PsheroTV   0.073315
# 842             PainLivestream   0.073150
# 381                       Kiwo   0.072708
# 673              Crocodyle_lol   0.072001
# 762                 Sweatcicle   0.071108
# 796                   cellinrj   0.070503
# 839                     Tourva   0.070148
# 559                     Criken   0.070014
# 716                      THump   0.069880
# 731                     Xposed   0.069785
# 914                 mandiocaa1   0.069645
# 419                      PENTA   0.069245
# 551           OfficialAndyPyro   0.069226
# 942               FantaBobShow   0.069217
# 717                    MaTaFe_   0.068879
# 308                   MarcaoRX   0.068831
# 643                    Broeki1   0.067573
# 589                      iLame   0.067427
# 861                 foggedftw2   0.066920
# 620              龜狗 (gueigotv)   0.066184
# 831                      Limmy   0.066179
# 742              Vargskelethor   0.065895
# 744                    LobosJr   0.064920
# 808                     chowh1   0.063802
# 369                     Ko0416   0.063313
# 300                 BurkeBlack   0.062648
# 751                       Vovo   0.062590
# 790                      AkTep   0.062012
# 804                  roflgator   0.061709
# 491                     flamuu   0.061153
# 985                   Surefour   0.061088
# 769                   Tanxlive   0.060449
# 766                  Alkaizerx   0.060329
# 807                    DieHahn   0.060116
# 820                     Herdyn   0.060087
# 729                      BreaK   0.059079
# 505            theRealShooKon3   0.058921
# 897                Ezekiel_III   0.058792
# 786            ProfessorBroman   0.058674
# 581                  skill4ltu   0.058591
# 909                      MuTeX   0.057905
# 698                  BRNWOWZK1   0.057369
# 889                    JonBams   0.056581
# 655                  gabepeixe   0.056325
# 503                   CuteDog_   0.056315
# 849                   Spaceboy   0.056299
# 683                 Drjayfisto   0.055619
# 760                   Cryaotic   0.055529
# 555                    BikeMan   0.054166
# 834                   CoconutB   0.053257
# 910               RayNarvaezJr   0.053095
# 801                      CaMaK   0.052696
# 940            西門夜說 (westdoor)   0.049573
# 778            BananaSlamJamma   0.049100
# 693          Zombie_Barricades   0.048769
# 975               TommyKayLIVE   0.048115
# 648                 SheriffEli   0.047871
# 824                    H0llyLP   0.045977
# 939                 Krayn_Live   0.045767
# 735                     CrReaM   0.043454
# 993          LAGTVMaximusBlack   0.042535
# 859                  MANvsGAME   0.041561
# 813             小夜夜 (albislol)   0.040535
# 891                OuterHeaven   0.039016
# 972                    HeyarTV   0.035869
# 779                      Dyrus   0.031403
# 42                    ROSHTEIN   0.000000
# 172                CasinoDaddy   0.000000
# 181                 ClassyBeef   0.000000
#
# Ranking Based on WASSPASS Score:
#                        Channel  WASSPASS Score
# 2                       Gaules        0.787091
# 15              MontanaBlack88        0.650222
# 10                TimTheTatman        0.626794
# 24               TheRealKnossi        0.616381
# 16                  sodapoppin        0.447052
# 84                     ZeratoR        0.423355
# 45                    Sardoche        0.385313
# 77                    Rainbow6        0.371357
# 212                 AustinShow        0.361621
# 171                Reborn_Live        0.342128
# 167                       wtcN        0.316646
# 74                    Symfuhny        0.316322
# 431                   JokerdTV        0.297150
# 927  Call of Duty (callofduty)        0.296370
# 176            KendineMuzisyen        0.289229
# 55                       Gorgc        0.288651
# 80               Trainwreckstv        0.283094
# 119                       aceu        0.279830
# 71                      forsen        0.273570
# 114                     TeePee        0.270934
# 231                INSCOPE21TV        0.268609
# 179                  Greekgodx        0.264526
# 32                    MOONMOON        0.262062
# 568             ElcanaldeJoaco        0.260201
# 339                     scoped        0.256199
# 988           CallMeCarsonLIVE        0.252324
# 63                      Quin69        0.251138
# 244                   Nadeshot        0.250650
# 168                      Anton        0.247382
# 489                    Arteezy        0.244972
# 218                      Aydan        0.242577
# 126                   DreadzTV        0.239535
# 65                    dasMEHDI        0.232233
# 711                   Pimpeano        0.229332
# 226                   mistermv        0.229133
# 116                   Agraelus        0.224415
# 182                 Diegosaurs        0.220785
# 89              AdmiralBulldog        0.216129
# 140                     RATIRL        0.211976
# 353                    ELoTRiX        0.211972
# 821                Frankkaster        0.211431
# 70                       Vader        0.209948
# 404              limit_maximum        0.204991
# 295                   Homyatol        0.203329
# 249                   HoneyMad        0.202169
# 138                    Destiny        0.199133
# 137            老皮 (mobilmobil)        0.198386
# 145          木棉花官方頻道 (muse_tw)        0.195044
# 793                Sweet_Anita        0.193288
# 816                   Stewie2K        0.193229
# 623                       zEkO        0.192871
# 197                  Vinesauce        0.190218
# 298                  boyMinORu        0.185662
# 660                      Datto        0.184984
# 416                  AlphaCast        0.184831
# 468                   Rammus53        0.184811
# 301                    Trick2g        0.184243
# 498                       WOKE        0.183629
# 273                  A_Seagull        0.183101
# 679                     Tyceno        0.182776
# 361               ALOHADANCETV        0.182570
# 230                 melharucos        0.182556
# 481                     Kotton        0.181434
# 374                   tarzaned        0.180095
# 242                    mch_AGG        0.179536
# 331                   MinosTV_        0.179401
# 526                  Skadoodle        0.178300
# 211                      B0aty        0.178153
# 184                    Nick28T        0.175955
# 466                   1DrakoNz        0.175826
# 666               GhostFreak66        0.175013
# 166                 RatedEpicz        0.174621
# 329                       NymN        0.174606
# 254                   Sequisha        0.174279
# 382                     adolfz        0.173501
# 867                   EFEUYGAC        0.172777
# 606                  Peereira7        0.170277
# 495                      maxim        0.169387
# 248                 嬌兔 (zrush)        0.169037
# 524                      Mendo        0.168864
# 280                 StaysafeTV        0.168675
# 624                   x6FlipiN        0.168503
# 190                김도 (kimdoe)        0.168278
# 752                     goncho        0.167485
# 434                   Jerma985        0.166712
# 688                     Maghla        0.166480
# 573                 WeAreTheVR        0.165924
# 296                    Grimmmz        0.165530
# 810                    natalan        0.164782
# 674                    WARDELL        0.164567
# 583                    Worrun_        0.164390
# 826                RobertoCein        0.164116
# 548                   Heelmike        0.163811
# 274                       koil        0.163648
# 216                       Kyle        0.162500
# 638               SovietWomble        0.161180
# 368          AvoidingThePuddle        0.160345
# 480                      MoMaN        0.159283
# 774                      dizzy        0.159089
# 873                AnniTheDuck        0.158911
# 538                  ItsSlikeR        0.158572
# 783                  Kandyland        0.158143
# 245                     buddha        0.157623
# 259              BarbarousKing        0.157317
# 453                   KabajiOW        0.156993
# 653                      Pengu        0.156706
# 882                  akagreenn        0.156520
# 323                   singsing        0.156470
# 508                    GTimeTV        0.155312
# 270                   Aurateur        0.155074
# 286                      Shotz        0.154877
# 901                  innocents        0.154831
# 345                      sips_        0.153138
# 484                   pijack11        0.152838
# 315                Distortion2        0.151781
# 365                 RoyalPhunk        0.151195
# 366                    Overpow        0.150974
# 458                        cyr        0.150455
# 307                   ANGRYPUG        0.150327
# 308                   MarcaoRX        0.150131
# 705              超負荷 (sam1268)        0.148376
# 592                      mang0        0.148015
# 911                   Tanovich        0.147129
# 467                     Pace22        0.147047
# 381                       Kiwo        0.145944
# 387              The_Happy_Hob        0.145841
# 421                     uhSnow        0.145218
# 512               GrandPOObear        0.145085
# 406                  guit88man        0.144455
# 519                   PsheroTV        0.143767
# 727                  DougisRaw        0.143741
# 698                  BRNWOWZK1        0.143734
# 551           OfficialAndyPyro        0.143696
# 839                     Tourva        0.143420
# 960                       Hype        0.142635
# 545                      Lasqa        0.142191
# 369                     Ko0416        0.141536
# 848                     trihex        0.141152
# 762                 Sweatcicle        0.141130
# 589                      iLame        0.140851
# 731                     Xposed        0.140116
# 717                    MaTaFe_        0.139997
# 914                 mandiocaa1        0.139799
# 842             PainLivestream        0.139518
# 673              Crocodyle_lol        0.139075
# 796                   cellinrj        0.139034
# 419                      PENTA        0.138856
# 716                      THump        0.138757
# 300                 BurkeBlack        0.138534
# 559                     Criken        0.137875
# 643                    Broeki1        0.137195
# 831                      Limmy        0.136573
# 861                 foggedftw2        0.136501
# 620              龜狗 (gueigotv)        0.136240
# 942               FantaBobShow        0.136215
# 808                     chowh1        0.135144
# 742              Vargskelethor        0.134913
# 751                       Vovo        0.134911
# 744                    LobosJr        0.134074
# 769                   Tanxlive        0.133712
# 491                     flamuu        0.132946
# 820                     Herdyn        0.132885
# 503                   CuteDog_        0.132503
# 505            theRealShooKon3        0.132397
# 909                      MuTeX        0.132202
# 581                  skill4ltu        0.131602
# 804                  roflgator        0.131509
# 790                      AkTep        0.131360
# 786            ProfessorBroman        0.131074
# 807                    DieHahn        0.130708
# 897                Ezekiel_III        0.130416
# 683                 Drjayfisto        0.130380
# 766                  Alkaizerx        0.129862
# 729                      BreaK        0.129858
# 985                   Surefour        0.129737
# 693          Zombie_Barricades        0.128616
# 555                    BikeMan        0.128053
# 655                  gabepeixe        0.127766
# 889                    JonBams        0.127705
# 849                   Spaceboy        0.127554
# 834                   CoconutB        0.126392
# 760                   Cryaotic        0.126098
# 801                      CaMaK        0.125010
# 910               RayNarvaezJr        0.123955
# 648                 SheriffEli        0.123384
# 940            西門夜說 (westdoor)        0.122943
# 778            BananaSlamJamma        0.122381
# 975               TommyKayLIVE        0.122076
# 813             小夜夜 (albislol)        0.121816
# 939                 Krayn_Live        0.121440
# 824                    H0llyLP        0.121388
# 735                     CrReaM        0.120335
# 993          LAGTVMaximusBlack        0.119633
# 859                  MANvsGAME        0.117881
# 779                      Dyrus        0.115719
# 972                    HeyarTV        0.115221
# 891                OuterHeaven        0.114363
# 42                    ROSHTEIN        0.094138
# 181                 ClassyBeef        0.044573
# 172                CasinoDaddy        0.036129
# C:\Users\amine\AppData\Local\Temp\ipykernel_20636\2322289756.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["WSM Score"] = wsm_scores
# C:\Users\amine\AppData\Local\Temp\ipykernel_20636\2322289756.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["WPM Score"] = wpm_scores

# %% [markdown]
# #### 2- TOPSIS

# %%
# Define max/min criteria (modifiable)
criteria_types = ['max', 'max', 'max', 'max', 'max', 'max', 'max']

# Given AHP weights
ahp_weights = np.array([0.12, 0.119, 0.209, 0.233, 0.095, 0.06, 0.163])

# Convert Partnered (True/False) to numeric
df_final["Partnered"] = df_final["Partnered"].astype(int)

# Extract decision matrix (X) and Channel names
X = df_final[criteria].values
channels = df_final["Channel"].values

# Step 1: Normalize the decision matrix
norms = np.linalg.norm(X, axis=0)
X_norm = X / norms

# Step 2: Adjust for min/max criteria
for i, ctype in enumerate(criteria_types):
    if ctype == 'min':  
        X_norm[:, i] = 1 - X_norm[:, i]  # Flip values for minimization

# Step 3: Multiply by AHP weights
X_weighted = X_norm * ahp_weights

# Step 4: Compute ideal and anti-ideal solutions
ideal_solution = np.max(X_weighted, axis=0)   # Best values
anti_ideal_solution = np.min(X_weighted, axis=0)  # Worst values

# Step 5: Compute distances to ideal and anti-ideal solutions
dist_ideal = np.sqrt(np.sum((X_weighted - ideal_solution) ** 2, axis=1))
dist_anti_ideal = np.sqrt(np.sum((X_weighted - anti_ideal_solution) ** 2, axis=1))

# Step 6: Compute TOPSIS scores
topsis_score = dist_anti_ideal / (dist_ideal + dist_anti_ideal)

# Step 7: Rank alternatives
df_final["TOPSIS_Score"] = topsis_score
df_final["Rank"] = df_final["TOPSIS_Score"].rank(ascending=False)

# Step 8: Sort by rank
df_final_sorted = df_final.sort_values(by="Rank")

# Display final ranking
print("\nTOPSIS Results (AHP WEIGHTS):")
print(df_final_sorted[["Channel", "TOPSIS_Score", "Rank"]])
# Out:
# TOPSIS Results (AHP WEIGHTS):
#                        Channel  TOPSIS_Score   Rank
# 2                       Gaules      0.691764    1.0
# 15              MontanaBlack88      0.595617    2.0
# 24               TheRealKnossi      0.589476    3.0
# 10                TimTheTatman      0.548393    4.0
# 84                     ZeratoR      0.424820    5.0
# 16                  sodapoppin      0.403691    6.0
# 431                   JokerdTV      0.393331    7.0
# 927  Call of Duty (callofduty)      0.374119    8.0
# 212                 AustinShow      0.373712    9.0
# 171                Reborn_Live      0.304913   10.0
# 45                    Sardoche      0.304650   11.0
# 77                    Rainbow6      0.300615   12.0
# 489                    Arteezy      0.286545   13.0
# 167                       wtcN      0.224518   14.0
# 42                    ROSHTEIN      0.223916   15.0
# 168                      Anton      0.215275   16.0
# 74                    Symfuhny      0.214888   17.0
# 32                    MOONMOON      0.209623   18.0
# 568             ElcanaldeJoaco      0.209152   19.0
# 988           CallMeCarsonLIVE      0.209137   20.0
# 176            KendineMuzisyen      0.206971   21.0
# 55                       Gorgc      0.203523   22.0
# 71                      forsen      0.199891   23.0
# 119                       aceu      0.195335   24.0
# 404              limit_maximum      0.190483   25.0
# 231                INSCOPE21TV      0.182427   26.0
# 339                     scoped      0.181015   27.0
# 80               Trainwreckstv      0.179587   28.0
# 126                   DreadzTV      0.179275   29.0
# 114                     TeePee      0.175503   30.0
# 711                   Pimpeano      0.174786   31.0
# 244                   Nadeshot      0.172314   32.0
# 179                  Greekgodx      0.170503   33.0
# 63                      Quin69      0.166939   34.0
# 666               GhostFreak66      0.150829   35.0
# 226                   mistermv      0.146725   36.0
# 218                      Aydan      0.146168   37.0
# 65                    dasMEHDI      0.145321   38.0
# 89              AdmiralBulldog      0.144443   39.0
# 660                      Datto      0.139458   40.0
# 821                Frankkaster      0.139053   41.0
# 116                   Agraelus      0.137799   42.0
# 70                       Vader      0.137290   43.0
# 137            老皮 (mobilmobil)      0.135379   44.0
# 249                   HoneyMad      0.134406   45.0
# 353                    ELoTRiX      0.131894   46.0
# 793                Sweet_Anita      0.126264   47.0
# 140                     RATIRL      0.124180   48.0
# 182                 Diegosaurs      0.123755   49.0
# 816                   Stewie2K      0.123493   50.0
# 197                  Vinesauce      0.121576   51.0
# 145          木棉花官方頻道 (muse_tw)      0.120744   52.0
# 623                       zEkO      0.120096   53.0
# 295                   Homyatol      0.118333   54.0
# 242                    mch_AGG      0.117993   55.0
# 481                     Kotton      0.116778   56.0
# 498                       WOKE      0.115631   57.0
# 679                     Tyceno      0.115327   58.0
# 230                 melharucos      0.112436   59.0
# 810                    natalan      0.111365   60.0
# 298                  boyMinORu      0.110185   61.0
# 138                    Destiny      0.109491   62.0
# 190                김도 (kimdoe)      0.109265   63.0
# 361               ALOHADANCETV      0.107737   64.0
# 468                   Rammus53      0.106974   65.0
# 826                RobertoCein      0.105834   66.0
# 273                  A_Seagull      0.105744   67.0
# 382                     adolfz      0.105625   68.0
# 867                   EFEUYGAC      0.104301   69.0
# 374                   tarzaned      0.102461   70.0
# 606                  Peereira7      0.101540   71.0
# 434                   Jerma985      0.101438   72.0
# 416                  AlphaCast      0.100508   73.0
# 248                 嬌兔 (zrush)      0.099025   74.0
# 301                    Trick2g      0.098288   75.0
# 211                      B0aty      0.098034   76.0
# 526                  Skadoodle      0.097540   77.0
# 166                 RatedEpicz      0.096905   78.0
# 705              超負荷 (sam1268)      0.096755   79.0
# 466                   1DrakoNz      0.096408   80.0
# 583                    Worrun_      0.095928   81.0
# 184                    Nick28T      0.095289   82.0
# 329                       NymN      0.094736   83.0
# 331                   MinosTV_      0.094674   84.0
# 873                AnniTheDuck      0.093457   85.0
# 674                    WARDELL      0.093431   86.0
# 698                  BRNWOWZK1      0.093351   87.0
# 752                     goncho      0.092712   88.0
# 914                 mandiocaa1      0.092362   89.0
# 368          AvoidingThePuddle      0.092170   90.0
# 254                   Sequisha      0.091978   91.0
# 495                      maxim      0.091836   92.0
# 308                   MarcaoRX      0.091522   93.0
# 624                   x6FlipiN      0.091511   94.0
# 688                     Maghla      0.091349   95.0
# 638               SovietWomble      0.090971   96.0
# 573                 WeAreTheVR      0.090889   97.0
# 783                  Kandyland      0.090830   98.0
# 280                 StaysafeTV      0.090403   99.0
# 216                       Kyle      0.090313  100.0
# 296                    Grimmmz      0.090239  101.0
# 524                      Mendo      0.089965  102.0
# 245                     buddha      0.089749  103.0
# 653                      Pengu      0.089542  104.0
# 901                  innocents      0.089501  105.0
# 274                       koil      0.089306  106.0
# 548                   Heelmike      0.088426  107.0
# 369                     Ko0416      0.088242  108.0
# 774                      dizzy      0.087776  109.0
# 882                  akagreenn      0.086967  110.0
# 453                   KabajiOW      0.086745  111.0
# 323                   singsing      0.085565  112.0
# 270                   Aurateur      0.085545  113.0
# 259              BarbarousKing      0.085536  114.0
# 551           OfficialAndyPyro      0.085488  115.0
# 480                      MoMaN      0.085133  116.0
# 345                      sips_      0.084694  117.0
# 508                    GTimeTV      0.084611  118.0
# 366                    Overpow      0.084609  119.0
# 286                      Shotz      0.084454  120.0
# 538                  ItsSlikeR      0.084357  121.0
# 365                 RoyalPhunk      0.084247  122.0
# 421                     uhSnow      0.083331  123.0
# 839                     Tourva      0.082845  124.0
# 911                   Tanovich      0.082830  125.0
# 484                   pijack11      0.082731  126.0
# 381                       Kiwo      0.082515  127.0
# 406                  guit88man      0.082426  128.0
# 589                      iLame      0.082171  129.0
# 315                Distortion2      0.082130  130.0
# 387              The_Happy_Hob      0.082016  131.0
# 307                   ANGRYPUG      0.081972  132.0
# 181                 ClassyBeef      0.081652  133.0
# 545                      Lasqa      0.081633  134.0
# 300                 BurkeBlack      0.081468  135.0
# 592                      mang0      0.081429  136.0
# 458                        cyr      0.080739  137.0
# 727                  DougisRaw      0.080246  138.0
# 848                     trihex      0.079483  139.0
# 519                   PsheroTV      0.079032  140.0
# 467                     Pace22      0.078986  141.0
# 742              Vargskelethor      0.078804  142.0
# 512               GrandPOObear      0.078643  143.0
# 693          Zombie_Barricades      0.078037  144.0
# 419                      PENTA      0.077845  145.0
# 503                   CuteDog_      0.077557  146.0
# 960                       Hype      0.077549  147.0
# 762                 Sweatcicle      0.077499  148.0
# 731                     Xposed      0.077350  149.0
# 769                   Tanxlive      0.077191  150.0
# 717                    MaTaFe_      0.076972  151.0
# 813             小夜夜 (albislol)      0.076641  152.0
# 716                      THump      0.076422  153.0
# 620              龜狗 (gueigotv)      0.076281  154.0
# 796                   cellinrj      0.076267  155.0
# 643                    Broeki1      0.076214  156.0
# 831                      Limmy      0.076172  157.0
# 683                 Drjayfisto      0.075897  158.0
# 897                Ezekiel_III      0.075895  159.0
# 842             PainLivestream      0.075803  160.0
# 559                     Criken      0.075729  161.0
# 909                      MuTeX      0.075549  162.0
# 673              Crocodyle_lol      0.075403  163.0
# 820                     Herdyn      0.075340  164.0
# 751                       Vovo      0.075321  165.0
# 505            theRealShooKon3      0.075244  166.0
# 491                     flamuu      0.075215  167.0
# 942               FantaBobShow      0.075187  168.0
# 808                     chowh1      0.075050  169.0
# 985                   Surefour      0.074921  170.0
# 786            ProfessorBroman      0.074908  171.0
# 861                 foggedftw2      0.074868  172.0
# 581                  skill4ltu      0.074837  173.0
# 744                    LobosJr      0.074539  174.0
# 555                    BikeMan      0.074149  175.0
# 779                      Dyrus      0.073893  176.0
# 804                  roflgator      0.073759  177.0
# 729                      BreaK      0.073521  178.0
# 859                  MANvsGAME      0.073364  179.0
# 790                      AkTep      0.073250  180.0
# 655                  gabepeixe      0.073247  181.0
# 801                      CaMaK      0.073140  182.0
# 766                  Alkaizerx      0.073067  183.0
# 807                    DieHahn      0.073054  184.0
# 648                 SheriffEli      0.072922  185.0
# 993          LAGTVMaximusBlack      0.072696  186.0
# 939                 Krayn_Live      0.072571  187.0
# 735                     CrReaM      0.072517  188.0
# 849                   Spaceboy      0.072505  189.0
# 889                    JonBams      0.072378  190.0
# 760                   Cryaotic      0.072335  191.0
# 940            西門夜說 (westdoor)      0.072279  192.0
# 834                   CoconutB      0.072276  193.0
# 824                    H0llyLP      0.072221  194.0
# 972                    HeyarTV      0.071953  195.0
# 910               RayNarvaezJr      0.071461  196.0
# 778            BananaSlamJamma      0.071329  197.0
# 975               TommyKayLIVE      0.071171  198.0
# 891                OuterHeaven      0.069776  199.0
# 172                CasinoDaddy      0.067006  200.0

# %% [markdown]
# #### 3- PROMETHEE I and PROMETHEE II

# %%
# Extract relevant data
df_final = top_mature_streamers[["Channel"] + criteria]
matrix = df_final[criteria].values  # Convert to NumPy array
n, m = matrix.shape

# Define AHP weights
weights = np.array([0.12, 0.119, 0.209, 0.233, 0.095, 0.06, 0.163])
weights /= np.sum(weights)  # Normalize weights

# Define criteria types (1 = maximization, all are beneficial)
criteria_types = np.ones(m, dtype=int)

# PROMETHEE Functions
def normalize_promethee(matrix):
    """Normalize the decision matrix for PROMETHEE."""
    n, m = matrix.shape
    normalized_matrix = np.zeros((n, m), dtype=float)
    
    for j in range(m):
        col_min, col_max = np.min(matrix[:, j]), np.max(matrix[:, j])
        if col_max == col_min:  
            normalized_matrix[:, j] = 0.5  # Neutral value instead of 1
        else:
            normalized_matrix[:, j] = (matrix[:, j] - col_min) / (col_max - col_min)
    
    return normalized_matrix

def compute_promethee(matrix, weights):
    """Compute PROMETHEE I (partial ranking) and PROMETHEE II (complete ranking)."""
    n, m = matrix.shape
    normalized_matrix = normalize_promethee(matrix)

    # Compute pairwise preference differences
    pairwise_differences = np.zeros((n, n, m))
    for i in range(n):
        for j in range(n):
            pairwise_differences[i, j, :] = normalized_matrix[i, :] - normalized_matrix[j, :]

    # Compute preference function Pj(a,b)
    preference_matrix = np.maximum(pairwise_differences, 0)

    # Weighted preference matrix
    weighted_preference_matrix = np.multiply(preference_matrix, weights)

    # Priority matrix
    priority_matrix = np.sum(weighted_preference_matrix, axis=2)

    # Compute Phi+ (positive flow) and Phi- (negative flow)
    phi_plus = np.sum(priority_matrix, axis=1) / (n - 1)
    phi_minus = np.sum(priority_matrix, axis=0) / (n - 1)
    phi_net = phi_plus - phi_minus

    # -----------------------------
    # PROMETHEE I (Partial Ranking)
    # -----------------------------
    ranking_df = pd.DataFrame({
        "Channel": df_final["Channel"],
        "Phi+": phi_plus,
        "Phi-": phi_minus
    }).sort_values(by="Phi+", ascending=False).reset_index(drop=True)

    ranking_groups = {}
    for i in range(n):
        alternative = ranking_df.iloc[i]["Channel"]
        phi_p, phi_m = ranking_df.iloc[i]["Phi+"], ranking_df.iloc[i]["Phi-"]

        # Define relationships
        rank_label = f"Phi+={phi_p:.3f}, Phi-={phi_m:.3f}"
        if rank_label not in ranking_groups:
            ranking_groups[rank_label] = []
        ranking_groups[rank_label].append(alternative)

    # -----------------------------
    # PROMETHEE II (Complete Ranking)
    # -----------------------------
    ranking_df["Phi_Net"] = phi_net
    ranking_df = ranking_df.sort_values(by="Phi_Net", ascending=False).reset_index(drop=True)

    return normalized_matrix, priority_matrix, phi_plus, phi_minus, phi_net, ranking_groups, ranking_df

# Compute PROMETHEE results
normalized_matrix, priority_matrix, phi_plus, phi_minus, phi_net, ranking_groups, ranking_df = compute_promethee(matrix, weights)

# Display results
print("\nPROMETHEE I Ranking: (AHP WEIGHTS)")
for rank, alternatives in ranking_groups.items():
    print(f"{rank} -> {', '.join(alternatives)}")

# Show ranking dataframe
print("\nPROMETHEE II Ranking: (AHP WEIGHTS)")
print(ranking_df)  # Display top-ranked streamers
# Out:
# PROMETHEE I Ranking: (AHP WEIGHTS)
# Phi+=0.584, Phi-=0.004 -> Gaules
# Phi+=0.458, Phi-=0.009 -> MontanaBlack88
# Phi+=0.427, Phi-=0.010 -> TheRealKnossi
# Phi+=0.419, Phi-=0.006 -> TimTheTatman
# Phi+=0.246, Phi-=0.013 -> sodapoppin
# Phi+=0.234, Phi-=0.016 -> ZeratoR
# Phi+=0.212, Phi-=0.024 -> AustinShow
# Phi+=0.197, Phi-=0.037 -> Call of Duty (callofduty)
# Phi+=0.182, Phi-=0.023 -> Reborn_Live
# Phi+=0.177, Phi-=0.013 -> Sardoche
# Phi+=0.177, Phi-=0.031 -> JokerdTV
# Phi+=0.172, Phi-=0.016 -> Rainbow6
# Phi+=0.130, Phi-=0.016 -> Symfuhny
# Phi+=0.129, Phi-=0.020 -> wtcN
# Phi+=0.127, Phi-=0.039 -> Arteezy
# Phi+=0.120, Phi-=0.180 -> ROSHTEIN
# Phi+=0.116, Phi-=0.034 -> CallMeCarsonLIVE
# Phi+=0.116, Phi-=0.031 -> ElcanaldeJoaco
# Phi+=0.112, Phi-=0.021 -> aceu
# Phi+=0.111, Phi-=0.023 -> KendineMuzisyen
# Phi+=0.102, Phi-=0.021 -> Gorgc
# Phi+=0.097, Phi-=0.026 -> MOONMOON
# Phi+=0.095, Phi-=0.027 -> scoped
# Phi+=0.095, Phi-=0.023 -> forsen
# Phi+=0.095, Phi-=0.019 -> Trainwreckstv
# Phi+=0.094, Phi-=0.025 -> INSCOPE21TV
# Phi+=0.088, Phi-=0.035 -> Pimpeano
# Phi+=0.085, Phi-=0.029 -> Anton
# Phi+=0.085, Phi-=0.022 -> TeePee
# Phi+=0.084, Phi-=0.023 -> Greekgodx
# Phi+=0.083, Phi-=0.028 -> Nadeshot
# Phi+=0.077, Phi-=0.025 -> Quin69
# Phi+=0.075, Phi-=0.030 -> DreadzTV
# Phi+=0.069, Phi-=0.025 -> Aydan
# Phi+=0.066, Phi-=0.029 -> dasMEHDI
# Phi+=0.063, Phi-=0.041 -> limit_maximum
# Phi+=0.062, Phi-=0.039 -> 木棉花官方頻道 (muse_tw)
# Phi+=0.061, Phi-=0.045 -> mch_AGG
# Phi+=0.057, Phi-=0.030 -> mistermv
# Phi+=0.057, Phi-=0.031 -> AdmiralBulldog
# Phi+=0.057, Phi-=0.036 -> Frankkaster
# Phi+=0.056, Phi-=0.028 -> Agraelus
# Phi+=0.055, Phi-=0.032 -> Vader
# Phi+=0.052, Phi-=0.033 -> ELoTRiX
# Phi+=0.050, Phi-=0.039 -> Sweet_Anita
# Phi+=0.049, Phi-=0.028 -> Diegosaurs
# Phi+=0.049, Phi-=0.029 -> RATIRL
# Phi+=0.048, Phi-=0.035 -> 老皮 (mobilmobil)
# Phi+=0.046, Phi-=0.048 -> GhostFreak66
# Phi+=0.045, Phi-=0.036 -> HoneyMad
# Phi+=0.044, Phi-=0.040 -> Stewie2K
# Phi+=0.044, Phi-=0.038 -> zEkO
# Phi+=0.041, Phi-=0.034 -> Homyatol
# Phi+=0.041, Phi-=0.043 -> Datto
# Phi+=0.039, Phi-=0.042 -> Tyceno
# Phi+=0.038, Phi-=0.199 -> ClassyBeef
# Phi+=0.037, Phi-=0.047 -> natalan
# Phi+=0.037, Phi-=0.032 -> Destiny
# Phi+=0.036, Phi-=0.037 -> Vinesauce
# Phi+=0.035, Phi-=0.037 -> Rammus53
# Phi+=0.035, Phi-=0.055 -> BRNWOWZK1
# Phi+=0.035, Phi-=0.045 -> RobertoCein
# Phi+=0.033, Phi-=0.042 -> WOKE
# Phi+=0.032, Phi-=0.038 -> melharucos
# Phi+=0.032, Phi-=0.041 -> Peereira7
# Phi+=0.032, Phi-=0.051 -> MarcaoRX
# Phi+=0.032, Phi-=0.037 -> boyMinORu
# Phi+=0.031, Phi-=0.042 -> Kotton
# Phi+=0.031, Phi-=0.041 -> 김도 (kimdoe)
# Phi+=0.031, Phi-=0.043 -> EFEUYGAC
# Phi+=0.029, Phi-=0.039 -> ALOHADANCETV
# Phi+=0.028, Phi-=0.207 -> CasinoDaddy
# Phi+=0.028, Phi-=0.039 -> A_Seagull, tarzaned
# Phi+=0.028, Phi-=0.042 -> adolfz
# Phi+=0.028, Phi-=0.038 -> MinosTV_
# Phi+=0.027, Phi-=0.039 -> RatedEpicz
# Phi+=0.027, Phi-=0.038 -> AlphaCast, Nick28T
# Phi+=0.026, Phi-=0.037 -> Trick2g
# Phi+=0.026, Phi-=0.040 -> Skadoodle
# Phi+=0.026, Phi-=0.039 -> 1DrakoNz
# Phi+=0.026, Phi-=0.038 -> B0aty
# Phi+=0.026, Phi-=0.043 -> WARDELL
# Phi+=0.025, Phi-=0.041 -> 嬌兔 (zrush)
# Phi+=0.023, Phi-=0.046 -> AnniTheDuck
# Phi+=0.023, Phi-=0.044 -> Jerma985, goncho
# Phi+=0.023, Phi-=0.039 -> Sequisha
# Phi+=0.022, Phi-=0.040 -> NymN
# Phi+=0.022, Phi-=0.043 -> Maghla, Grimmmz
# Phi+=0.021, Phi-=0.048 -> innocents
# Phi+=0.021, Phi-=0.052 -> Ko0416
# Phi+=0.021, Phi-=0.045 -> Worrun_, SovietWomble
# Phi+=0.021, Phi-=0.043 -> x6FlipiN
# Phi+=0.021, Phi-=0.042 -> Kyle, Mendo
# Phi+=0.021, Phi-=0.046 -> GTimeTV, Kandyland
# Phi+=0.020, Phi-=0.046 -> Pengu
# Phi+=0.020, Phi-=0.043 -> Heelmike
# Phi+=0.020, Phi-=0.052 -> OfficialAndyPyro
# Phi+=0.020, Phi-=0.051 -> Kiwo
# Phi+=0.020, Phi-=0.040 -> StaysafeTV
# Phi+=0.020, Phi-=0.042 -> maxim
# Phi+=0.019, Phi-=0.045 -> BarbarousKing
# Phi+=0.019, Phi-=0.042 -> koil
# Phi+=0.018, Phi-=0.052 -> 超負荷 (sam1268)
# Phi+=0.018, Phi-=0.044 -> buddha, WeAreTheVR, MoMaN
# Phi+=0.018, Phi-=0.045 -> AvoidingThePuddle
# Phi+=0.017, Phi-=0.045 -> Aurateur
# Phi+=0.017, Phi-=0.059 -> Zombie_Barricades
# Phi+=0.017, Phi-=0.046 -> pijack11
# Phi+=0.016, Phi-=0.047 -> ANGRYPUG, dizzy, Overpow, Distortion2
# Phi+=0.016, Phi-=0.050 -> Tourva, Tanovich
# Phi+=0.016, Phi-=0.045 -> Shotz
# Phi+=0.016, Phi-=0.056 -> mandiocaa1
# Phi+=0.016, Phi-=0.048 -> akagreenn
# Phi+=0.016, Phi-=0.044 -> ItsSlikeR
# Phi+=0.015, Phi-=0.045 -> singsing
# Phi+=0.015, Phi-=0.051 -> BurkeBlack, iLame
# Phi+=0.015, Phi-=0.046 -> KabajiOW
# Phi+=0.015, Phi-=0.056 -> CuteDog_
# Phi+=0.014, Phi-=0.045 -> sips_
# Phi+=0.014, Phi-=0.051 -> PsheroTV, DougisRaw
# Phi+=0.014, Phi-=0.062 -> 小夜夜 (albislol)
# Phi+=0.014, Phi-=0.048 -> Pace22
# Phi+=0.014, Phi-=0.049 -> guit88man
# Phi+=0.013, Phi-=0.049 -> mang0
# Phi+=0.013, Phi-=0.047 -> RoyalPhunk
# Phi+=0.013, Phi-=0.048 -> cyr
# Phi+=0.012, Phi-=0.052 -> Sweatcicle
# Phi+=0.012, Phi-=0.050 -> uhSnow
# Phi+=0.012, Phi-=0.051 -> MaTaFe_
# Phi+=0.012, Phi-=0.049 -> The_Happy_Hob
# Phi+=0.012, Phi-=0.056 -> MuTeX
# Phi+=0.011, Phi-=0.052 -> Xposed
# Phi+=0.011, Phi-=0.055 -> Tanxlive
# Phi+=0.011, Phi-=0.053 -> trihex
# Phi+=0.010, Phi-=0.054 -> Vovo, chowh1
# Phi+=0.010, Phi-=0.055 -> theRealShooKon3
# Phi+=0.010, Phi-=0.052 -> Lasqa, PENTA
# Phi+=0.010, Phi-=0.056 -> Drjayfisto
# Phi+=0.010, Phi-=0.053 -> Limmy
# Phi+=0.010, Phi-=0.050 -> GrandPOObear
# Phi+=0.009, Phi-=0.057 -> ProfessorBroman
# Phi+=0.009, Phi-=0.051 -> Hype
# Phi+=0.009, Phi-=0.053 -> Broeki1, 龜狗 (gueigotv), foggedftw2
# Phi+=0.009, Phi-=0.052 -> THump, cellinrj
# Phi+=0.009, Phi-=0.054 -> Herdyn
# Phi+=0.009, Phi-=0.056 -> Vargskelethor
# Phi+=0.009, Phi-=0.063 -> LAGTVMaximusBlack
# Phi+=0.008, Phi-=0.054 -> skill4ltu, flamuu
# Phi+=0.008, Phi-=0.053 -> PainLivestream, Criken
# Phi+=0.008, Phi-=0.057 -> Ezekiel_III, BikeMan
# Phi+=0.008, Phi-=0.064 -> HeyarTV
# Phi+=0.008, Phi-=0.058 -> Dyrus
# Phi+=0.008, Phi-=0.052 -> Crocodyle_lol
# Phi+=0.008, Phi-=0.059 -> SheriffEli
# Phi+=0.007, Phi-=0.055 -> LobosJr, FantaBobShow
# Phi+=0.007, Phi-=0.061 -> CrReaM, Krayn_Live
# Phi+=0.007, Phi-=0.056 -> roflgator, DieHahn
# Phi+=0.007, Phi-=0.058 -> CoconutB
# Phi+=0.006, Phi-=0.059 -> Surefour
# Phi+=0.006, Phi-=0.060 -> H0llyLP, 西門夜說 (westdoor), TommyKayLIVE
# Phi+=0.006, Phi-=0.056 -> BreaK, AkTep
# Phi+=0.006, Phi-=0.058 -> Spaceboy, JonBams
# Phi+=0.006, Phi-=0.057 -> Alkaizerx, gabepeixe
# Phi+=0.005, Phi-=0.059 -> CaMaK, Cryaotic
# Phi+=0.005, Phi-=0.062 -> MANvsGAME
# Phi+=0.005, Phi-=0.060 -> BananaSlamJamma, RayNarvaezJr
# Phi+=0.004, Phi-=0.065 -> OuterHeaven
#
# PROMETHEE II Ranking: (AHP WEIGHTS)
#                        Channel      Phi+      Phi-   Phi_Net
# 0                      ZeratoR  0.233691  0.016187  0.579904
# 1               MontanaBlack88  0.458095  0.009114  0.448981
# 2                     ROSHTEIN  0.119716  0.180383  0.416560
# 3                       Gaules  0.583586  0.003683  0.413066
# 4                TheRealKnossi  0.426734  0.010175  0.233274
# 5                  INSCOPE21TV  0.093694  0.024972  0.217504
# 6                       TeePee  0.085019  0.021989  0.188411
# 7                     dasMEHDI  0.065838  0.028707  0.164532
# 8                       scoped  0.095321  0.027415  0.159758
# 9                     Agraelus  0.056200  0.028382  0.159138
# 10   Call of Duty (callofduty)  0.197065  0.037307  0.156517
# 11                       THump  0.009353  0.052326  0.145591
# 12                TimTheTatman  0.419464  0.006398  0.113940
# 13                  sodapoppin  0.246322  0.013048  0.108842
# 14                       Anton  0.085210  0.029042  0.090542
# 15                    Rainbow6  0.172487  0.015969  0.088130
# 16                      RATIRL  0.049235  0.029079  0.088016
# 17                      Quin69  0.076849  0.025485  0.084919
# 18            CallMeCarsonLIVE  0.116295  0.033700  0.082595
# 19                   AlphaCast  0.027052  0.037830  0.080395
# 20                 Frankkaster  0.057233  0.036209  0.076049
# 21                        wtcN  0.128687  0.019845  0.071657
# 22                      forsen  0.094982  0.023324  0.071286
# 23                  Diegosaurs  0.049466  0.027884  0.068722
# 24                    mistermv  0.057381  0.030230  0.067906
# 25                   Vinesauce  0.036452  0.036942  0.063030
# 26                     Arteezy  0.127227  0.039211  0.061049
# 27                  RoyalPhunk  0.013144  0.047081  0.056168
# 28                    JokerdTV  0.176870  0.031279  0.054797
# 29           木棉花官方頻道 (muse_tw)  0.061592  0.039440  0.053144
# 30                        zEkO  0.043877  0.038081  0.051365
# 31                     ELoTRiX  0.051608  0.033336  0.044547
# 32                  AustinShow  0.212193  0.023782  0.044000
# 33            OfficialAndyPyro  0.019882  0.052127  0.037132
# 34                   A_Seagull  0.028074  0.038548  0.027818
# 35                        WOKE  0.032989  0.041969  0.027151
# 36                       Vader  0.054749  0.032002  0.026517
# 37                ALOHADANCETV  0.028851  0.039343  0.022746
# 38                GrandPOObear  0.009503  0.049817  0.022262
# 39                     JonBams  0.005985  0.057877  0.022152
# 40                     Destiny  0.036741  0.032417  0.021581
# 41                   Greekgodx  0.084087  0.023038  0.021023
# 42                 CasinoDaddy  0.028191  0.206970  0.020156
# 43               Trainwreckstv  0.094954  0.018904  0.018272
# 44                      Pace22  0.013794  0.048210  0.015956
# 45                   Peereira7  0.032383  0.041338  0.012064
# 46                    MOONMOON  0.097117  0.025830  0.010942
# 47                       Datto  0.040733  0.043480  0.008928
# 48                    1DrakoNz  0.026336  0.038677  0.007629
# 49               limit_maximum  0.063256  0.040994  0.005796
# 50                    Pimpeano  0.088430  0.035286  0.004745
# 51                    HoneyMad  0.044997  0.036069  0.004324
# 52                    MarcaoRX  0.032221  0.051020 -0.000490
# 53             KendineMuzisyen  0.111211  0.023081 -0.001716
# 54                       CaMaK  0.005430  0.058783 -0.001779
# 55                      Tyceno  0.038548  0.041904 -0.002747
# 56                  StaysafeTV  0.019716  0.040323 -0.003355
# 57                 AnniTheDuck  0.023415  0.046489 -0.005385
# 58                    x6FlipiN  0.020933  0.043124 -0.005488
# 59                   Skadoodle  0.026440  0.039569 -0.008955
# 60                RayNarvaezJr  0.004551  0.060476 -0.008980
# 61                  ClassyBeef  0.037763  0.199497 -0.009251
# 62                         cyr  0.013141  0.047687 -0.009602
# 63               超負荷 (sam1268)  0.018473  0.052180 -0.009892
# 64                 Reborn_Live  0.181754  0.022617 -0.010071
# 65              AdmiralBulldog  0.057362  0.030846 -0.010420
# 66              ElcanaldeJoaco  0.116181  0.031262 -0.010474
# 67                    Stewie2K  0.044276  0.039532 -0.010492
# 68                   akagreenn  0.015666  0.047996 -0.010626
# 69                      adolfz  0.028030  0.041854 -0.010778
# 70                     Nick28T  0.026675  0.038339 -0.011062
# 71                      CrReaM  0.007272  0.060766 -0.011534
# 72                       Gorgc  0.101520  0.021126 -0.011664
# 73                      goncho  0.022717  0.043535 -0.012058
# 74                   BRNWOWZK1  0.034952  0.055200 -0.012238
# 75                     WARDELL  0.025626  0.042828 -0.012341
# 76             老皮 (mobilmobil)  0.047501  0.035437 -0.013129
# 77                        koil  0.019012  0.042040 -0.013823
# 78                 Distortion2  0.015543  0.046609 -0.015686
# 79                      trihex  0.010919  0.052578 -0.016300
# 80                    Heelmike  0.020118  0.043035 -0.017202
# 81                       sips_  0.014419  0.045456 -0.017620
# 82                       Limmy  0.009794  0.053473 -0.018799
# 83                        Vovo  0.010489  0.053894 -0.020249
# 84                   skill4ltu  0.008467  0.054453 -0.020607
# 85                        aceu  0.111523  0.020981 -0.020751
# 86                   boyMinORu  0.031798  0.037183 -0.020818
# 87                      Ko0416  0.021153  0.051717 -0.021118
# 88                      Xposed  0.011420  0.051585 -0.021174
# 89                     Grimmmz  0.021875  0.042625 -0.021240
# 90                    Rammus53  0.035413  0.037128 -0.021330
# 91                    Aurateur  0.017478  0.045434 -0.022191
# 92                   Kandyland  0.020708  0.045735 -0.022644
# 93                       Pengu  0.020364  0.045936 -0.022917
# 94                        Kiwo  0.019784  0.050995 -0.023029
# 95                  melharucos  0.032461  0.037949 -0.023075
# 96                    Symfuhny  0.130339  0.016399 -0.023984
# 97                     HeyarTV  0.008054  0.064253 -0.024339
# 98                  RatedEpicz  0.027053  0.038586 -0.025027
# 99                 Sweet_Anita  0.049579  0.038637 -0.025220
# 100                      Aydan  0.068920  0.024920 -0.025572
# 101                    Broeki1  0.009358  0.053114 -0.025620
# 102                 BurkeBlack  0.015143  0.051093 -0.025735
# 103                   MinosTV_  0.027906  0.037508 -0.025756
# 104                   Homyatol  0.041286  0.033657 -0.026339
# 105                   Sequisha  0.023143  0.038830 -0.026522
# 106                     Maghla  0.021926  0.043045 -0.027126
# 107                      Dyrus  0.007751  0.058380 -0.027956
# 108          AvoidingThePuddle  0.017690  0.044816 -0.028626
# 109                       Hype  0.009415  0.051393 -0.028851
# 110                  ItsSlikeR  0.015603  0.044229 -0.028939
# 111               GhostFreak66  0.045747  0.047526 -0.029308
# 112                  MANvsGAME  0.005340  0.061840 -0.030564
# 113                   DreadzTV  0.074572  0.030026 -0.030670
# 114                   Jerma985  0.023144  0.044384 -0.030890
# 115                   EFEUYGAC  0.031270  0.043328 -0.031037
# 116                       Kyle  0.020928  0.042102 -0.031066
# 117              BarbarousKing  0.019299  0.044919 -0.031211
# 118                    Overpow  0.015792  0.047009 -0.031216
# 119                 嬌兔 (zrush)  0.024670  0.040970 -0.031381
# 120                   Tanovich  0.015897  0.049802 -0.032245
# 121                  Alkaizerx  0.005974  0.057259 -0.032330
# 122             PainLivestream  0.008246  0.052989 -0.033706
# 123                     buddha  0.018421  0.044156 -0.033859
# 124                      maxim  0.019604  0.042248 -0.033905
# 125                 Sweatcicle  0.012194  0.051653 -0.033937
# 126                      Lasqa  0.010309  0.051812 -0.034416
# 127                   Tanxlive  0.011356  0.054974 -0.034547
# 128                    BikeMan  0.007829  0.056503 -0.035722
# 129          Zombie_Barricades  0.016965  0.059113 -0.035950
# 130                    Worrun_  0.021105  0.045443 -0.036080
# 131                   PsheroTV  0.014313  0.050586 -0.036205
# 132                     uhSnow  0.011976  0.049836 -0.036273
# 133                  guit88man  0.013556  0.049278 -0.037178
# 134                   Surefour  0.006437  0.058725 -0.037425
# 135                 Krayn_Live  0.007128  0.060743 -0.037860
# 136            ProfessorBroman  0.009432  0.056602 -0.039459
# 137                  gabepeixe  0.005960  0.057407 -0.039472
# 138                   ANGRYPUG  0.016453  0.047342 -0.040165
# 139                 mandiocaa1  0.015777  0.056231 -0.040314
# 140                    GTimeTV  0.020917  0.046137 -0.040454
# 141                    LobosJr  0.007385  0.054786 -0.041503
# 142                김도 (kimdoe)  0.031366  0.041258 -0.041658
# 143            西門夜說 (westdoor)  0.005625  0.060035 -0.041855
# 144                     Criken  0.007864  0.052693 -0.041979
# 145                     Herdyn  0.009130  0.054087 -0.042025
# 146            theRealShooKon3  0.010483  0.055193 -0.042149
# 147                   singsing  0.015228  0.044535 -0.042974
# 148                      iLame  0.014945  0.051149 -0.043054
# 149              Crocodyle_lol  0.007747  0.052195 -0.043404
# 150                   KabajiOW  0.014738  0.046119 -0.043618
# 151                      mang0  0.013374  0.049454 -0.043679
# 152          LAGTVMaximusBlack  0.008711  0.062728 -0.043756
# 153               TommyKayLIVE  0.005583  0.060311 -0.044157
# 154                    MaTaFe_  0.011960  0.051432 -0.044187
# 155                      PENTA  0.009648  0.051672 -0.044274
# 156                   Cryaotic  0.005043  0.059075 -0.044448
# 157                   CuteDog_  0.014540  0.056395 -0.044576
# 158                    H0llyLP  0.006435  0.060350 -0.044711
# 159                     Kotton  0.031480  0.042106 -0.044743
# 160                      MoMaN  0.017694  0.044215 -0.044828
# 161                   tarzaned  0.027667  0.038729 -0.044958
# 162                  roflgator  0.007058  0.056433 -0.045468
# 163                      AkTep  0.005961  0.055920 -0.045830
# 164                   CoconutB  0.006692  0.057879 -0.045986
# 165                 WeAreTheVR  0.017975  0.043731 -0.046642
# 166                    mch_AGG  0.060950  0.044994 -0.047170
# 167                      B0aty  0.026096  0.038334 -0.047401
# 168                       NymN  0.022025  0.039645 -0.047436
# 169                Ezekiel_III  0.008120  0.056730 -0.047548
# 170              The_Happy_Hob  0.011691  0.048869 -0.048610
# 171                     Tourva  0.016187  0.050046 -0.048674
# 172             小夜夜 (albislol)  0.014218  0.061766 -0.049374
# 173                OuterHeaven  0.004058  0.065168 -0.049375
# 174                  DougisRaw  0.013905  0.051331 -0.049958
# 175                      Mendo  0.020565  0.041895 -0.050013
# 176                   Sardoche  0.177230  0.012698 -0.050629
# 177                      MuTeX  0.011539  0.055726 -0.051187
# 178                   cellinrj  0.009255  0.052309 -0.051286
# 179                     flamuu  0.008288  0.054118 -0.051447
# 180                      dizzy  0.016305  0.046974 -0.051777
# 181               SovietWomble  0.020685  0.044670 -0.051892
# 182               FantaBobShow  0.007315  0.054750 -0.051898
# 183                  innocents  0.021291  0.047630 -0.052288
# 184              龜狗 (gueigotv)  0.009025  0.053299 -0.053353
# 185                     chowh1  0.009692  0.053849 -0.053493
# 186                      BreaK  0.006425  0.056438 -0.053615
# 187                 foggedftw2  0.008780  0.053356 -0.053916
# 188                      Shotz  0.016021  0.044873 -0.054018
# 189                   Nadeshot  0.082733  0.027937 -0.054031
# 190                   pijack11  0.016586  0.045525 -0.054410
# 191                    DieHahn  0.006746  0.056120 -0.054729
# 192                 Drjayfisto  0.010229  0.055697 -0.055070
# 193                    natalan  0.037335  0.046585 -0.055925
# 194                   Spaceboy  0.006355  0.058252 -0.056199
# 195                RobertoCein  0.034681  0.045100 -0.056500
# 196                    Trick2g  0.026480  0.036551 -0.060666
# 197                 SheriffEli  0.007504  0.059281 -0.061110
# 198            BananaSlamJamma  0.005293  0.060363 -0.161734
# 199              Vargskelethor  0.008890  0.055532 -0.178779

# %% [markdown]
# ### III- ENTROPY WEIGHTS

# %%
# Function to normalize the matrix column-wise so that each column sums to 1.
def normalize_matrix_columnwise(mat):
    col_sums = np.sum(mat, axis=0)
    return mat / col_sums

# Function to compute the entropy for each criterion (column)
def compute_entropy(matrix):
    n, m = matrix.shape  # n: number of alternatives, m: number of criteria
    k = 1 / np.log(float(n))  # Ensure n is treated as a float
    epsilon = 1e-10  # Small constant to avoid log(0)
    
    # Ensure matrix is of type float64
    matrix = np.array(matrix, dtype=np.float64)
    
    # Compute entropy formula
    pij_ln_pij = np.where(matrix > 0, matrix * np.log1p(matrix - 1 + epsilon), 0)
    column_sums = np.sum(pij_ln_pij, axis=0)
    entropy_values = -k * column_sums
    return entropy_values

# --- Assuming df_final and criteria are already defined ---
decision_matrix = df_final[criteria].values

# Ensure decision_matrix is a float64 array
decision_matrix = np.array(decision_matrix, dtype=np.float64)

# Normalize the decision matrix column-wise
normalized_matrix_entropy = normalize_matrix_columnwise(decision_matrix)

# Compute entropy values for each criterion
entropy_values = compute_entropy(normalized_matrix_entropy)

# Compute diversity (d_j = 1 - E_j)
diversity = 1 - entropy_values

# Compute entropy weights (w_j = d_j / sum(d_j))
entropy_weights = diversity / np.sum(diversity)

# Display the entropy weights
print("Entropy Weights for each criterion:")
print(entropy_weights)
# Out:
# Entropy Weights for each criterion:
# [0.21041816 0.14298389 0.25862418 0.16473849 0.16506985 0.05258346
#  0.00558197]

# %%
entropy_weights = np.array([0.21041816, 0.14298389, 0.25862418, 0.16473849, 
                            0.16506985, 0.05258346, 0.00558197])

# %% [markdown]
# #### 1- WSM, WPM and WASPAS

# %%
# ------------------------------------------------------------------------------
# Function Definitions
# ------------------------------------------------------------------------------
def generate_criteria_type_matrix(m):
    """Generate criteria type matrix (1 = maximization criteria)."""
    return np.ones((1, m))  # All criteria are maximization

def normalize_matrix_max(mat, criteria_types):
    """Normalize decision matrix using max normalization."""
    normalized_matrix = np.zeros_like(mat, dtype=float)
    for j in range(mat.shape[1]):
        if criteria_types[0, j] == 1:  # Maximization
            normalized_matrix[:, j] = mat[:, j] / np.max(mat[:, j])
    return normalized_matrix

def compute_wsm_score(normalized_matrix, weights):
    """Compute Weighted Sum Model (WSM) scores."""
    return np.sum(normalized_matrix * weights, axis=1)

def compute_wpm_score(normalized_matrix, weights):
    """Compute Weighted Product Model (WPM) scores."""
    return np.prod(normalized_matrix ** weights, axis=1)

def compute_wasspass_score(wsm_scores, wpm_scores, lambda_value=0.5):
    """Compute WASSPASS scores (combining WSM and WPM)."""
    return lambda_value * wsm_scores + (1 - lambda_value) * wpm_scores

# ------------------------------------------------------------------------------
# Data Processing and Ranking
# ------------------------------------------------------------------------------

# Extract decision matrix
decision_matrix = df_final[criteria].values

# Normalize the matrix using max normalization
m = decision_matrix.shape[1]
criteria_types = generate_criteria_type_matrix(m)
normalized_matrix = normalize_matrix_max(decision_matrix, criteria_types)

# Compute scores using Entropy Weights
wsm_scores = compute_wsm_score(normalized_matrix, entropy_weights)
wpm_scores = compute_wpm_score(normalized_matrix, entropy_weights)
wasspass_scores = compute_wasspass_score(wsm_scores, wpm_scores, lambda_value=0.5)

# Append scores to DataFrame
df_final["WSM Score"] = wsm_scores
df_final["WPM Score"] = wpm_scores
df_final["WASSPASS Score"] = wasspass_scores

# Rank alternatives for each method separately
df_wsm_ranking = df_final.sort_values(by="WSM Score", ascending=False)
df_wpm_ranking = df_final.sort_values(by="WPM Score", ascending=False)
df_wasspass_ranking = df_final.sort_values(by="WASSPASS Score", ascending=False)

# ------------------------------------------------------------------------------
# Display Results in Separate Tables
# ------------------------------------------------------------------------------
print("\nRanking Based on WSM Score (Entropy Weights):")
print(df_wsm_ranking[["Channel", "WSM Score"]])

print("\nRanking Based on WPM Score (Entropy Weights):")
print(df_wpm_ranking[["Channel", "WPM Score"]])

print("\nRanking Based on WASSPASS Score (Entropy Weights):")
print(df_wasspass_ranking[["Channel", "WASSPASS Score"]])
# Out:
# Ranking Based on WSM Score (Entropy Weights):
#                        Channel  WSM Score
# 2                       Gaules   0.851917
# 15              MontanaBlack88   0.606944
# 10                TimTheTatman   0.600845
# 24               TheRealKnossi   0.596077
# 84                     ZeratoR   0.355130
# 16                  sodapoppin   0.348856
# 45                    Sardoche   0.305573
# 431                   JokerdTV   0.288571
# 77                    Rainbow6   0.287224
# 171                Reborn_Live   0.279654
# 212                 AustinShow   0.272707
# 74                    Symfuhny   0.262825
# 167                       wtcN   0.247431
# 119                       aceu   0.239227
# 927  Call of Duty (callofduty)   0.237256
# 568             ElcanaldeJoaco   0.223616
# 988           CallMeCarsonLIVE   0.220812
# 339                     scoped   0.213497
# 176            KendineMuzisyen   0.211066
# 42                    ROSHTEIN   0.208175
# 80               Trainwreckstv   0.200248
# 231                INSCOPE21TV   0.194699
# 55                       Gorgc   0.189249
# 711                   Pimpeano   0.188034
# 114                     TeePee   0.184401
# 179                  Greekgodx   0.182026
# 71                      forsen   0.175008
# 168                      Anton   0.174974
# 244                   Nadeshot   0.173199
# 218                      Aydan   0.173108
# 32                    MOONMOON   0.169775
# 63                      Quin69   0.157179
# 489                    Arteezy   0.153452
# 126                   DreadzTV   0.146996
# 65                    dasMEHDI   0.143277
# 793                Sweet_Anita   0.140954
# 821                Frankkaster   0.138467
# 182                 Diegosaurs   0.136543
# 404              limit_maximum   0.135581
# 116                   Agraelus   0.134911
# 140                     RATIRL   0.132556
# 353                    ELoTRiX   0.130714
# 226                   mistermv   0.129596
# 145          木棉花官方頻道 (muse_tw)   0.126988
# 89              AdmiralBulldog   0.126492
# 70                       Vader   0.122649
# 623                       zEkO   0.122019
# 242                    mch_AGG   0.117933
# 295                   Homyatol   0.117007
# 468                   Rammus53   0.116899
# 810                    natalan   0.115663
# 816                   Stewie2K   0.113928
# 826                RobertoCein   0.113569
# 606                  Peereira7   0.111256
# 137            老皮 (mobilmobil)   0.109027
# 666               GhostFreak66   0.108789
# 138                    Destiny   0.107972
# 679                     Tyceno   0.106501
# 660                      Datto   0.104918
# 249                   HoneyMad   0.104083
# 181                 ClassyBeef   0.100491
# 331                   MinosTV_   0.099237
# 867                   EFEUYGAC   0.099099
# 466                   1DrakoNz   0.098694
# 674                    WARDELL   0.097591
# 526                  Skadoodle   0.097556
# 298                  boyMinORu   0.096575
# 416                  AlphaCast   0.094888
# 197                  Vinesauce   0.094361
# 301                    Trick2g   0.094045
# 230                 melharucos   0.093987
# 498                       WOKE   0.093027
# 481                     Kotton   0.092904
# 374                   tarzaned   0.092105
# 688                     Maghla   0.089330
# 752                     goncho   0.089258
# 184                    Nick28T   0.088233
# 361               ALOHADANCETV   0.088174
# 873                AnniTheDuck   0.087589
# 166                 RatedEpicz   0.087538
# 901                  innocents   0.086912
# 273                  A_Seagull   0.086642
# 211                      B0aty   0.086528
# 524                      Mendo   0.086304
# 382                     adolfz   0.085537
# 548                   Heelmike   0.085369
# 254                   Sequisha   0.085311
# 190                김도 (kimdoe)   0.084709
# 624                   x6FlipiN   0.084267
# 783                  Kandyland   0.083614
# 653                      Pengu   0.083433
# 329                       NymN   0.083086
# 638               SovietWomble   0.082673
# 248                 嬌兔 (zrush)   0.081535
# 508                    GTimeTV   0.080350
# 583                    Worrun_   0.079978
# 495                      maxim   0.079028
# 280                 StaysafeTV   0.078357
# 308                   MarcaoRX   0.077583
# 480                      MoMaN   0.077458
# 296                    Grimmmz   0.077160
# 698                  BRNWOWZK1   0.077108
# 172                CasinoDaddy   0.076847
# 216                       Kyle   0.076135
# 538                  ItsSlikeR   0.075055
# 484                   pijack11   0.074926
# 911                   Tanovich   0.074827
# 573                 WeAreTheVR   0.074225
# 274                       koil   0.074157
# 434                   Jerma985   0.073858
# 839                     Tourva   0.072755
# 259              BarbarousKing   0.071087
# 774                      dizzy   0.069900
# 245                     buddha   0.068861
# 368          AvoidingThePuddle   0.067964
# 882                  akagreenn   0.067643
# 286                      Shotz   0.067574
# 270                   Aurateur   0.067473
# 323                   singsing   0.066827
# 467                     Pace22   0.066606
# 345                      sips_   0.066400
# 453                   KabajiOW   0.066128
# 307                   ANGRYPUG   0.065928
# 315                Distortion2   0.065855
# 366                    Overpow   0.064892
# 381                       Kiwo   0.064885
# 369                     Ko0416   0.064504
# 551           OfficialAndyPyro   0.064098
# 458                        cyr   0.063132
# 762                 Sweatcicle   0.062879
# 731                     Xposed   0.062834
# 592                      mang0   0.062385
# 589                      iLame   0.062287
# 727                  DougisRaw   0.062205
# 519                   PsheroTV   0.061599
# 717                    MaTaFe_   0.061198
# 365                 RoyalPhunk   0.060587
# 406                  guit88man   0.059585
# 960                       Hype   0.058276
# 831                      Limmy   0.058057
# 796                   cellinrj   0.057949
# 300                 BurkeBlack   0.057635
# 387              The_Happy_Hob   0.057056
# 716                      THump   0.057052
# 909                      MuTeX   0.056839
# 861                 foggedftw2   0.056205
# 751                       Vovo   0.056189
# 421                     uhSnow   0.055951
# 705              超負荷 (sam1268)   0.055866
# 512               GrandPOObear   0.055501
# 848                     trihex   0.055471
# 808                     chowh1   0.055053
# 820                     Herdyn   0.054439
# 842             PainLivestream   0.054040
# 693          Zombie_Barricades   0.053869
# 673              Crocodyle_lol   0.053487
# 769                   Tanxlive   0.052695
# 419                      PENTA   0.052636
# 503                   CuteDog_   0.052267
# 545                      Lasqa   0.051723
# 643                    Broeki1   0.051659
# 620              龜狗 (gueigotv)   0.051075
# 942               FantaBobShow   0.050679
# 505            theRealShooKon3   0.050421
# 683                 Drjayfisto   0.050414
# 559                     Criken   0.050240
# 581                  skill4ltu   0.049681
# 914                 mandiocaa1   0.048862
# 491                     flamuu   0.048755
# 786            ProfessorBroman   0.047950
# 744                    LobosJr   0.047914
# 742              Vargskelethor   0.047705
# 804                  roflgator   0.047149
# 807                    DieHahn   0.046560
# 897                Ezekiel_III   0.046312
# 790                      AkTep   0.046305
# 834                   CoconutB   0.045553
# 813             小夜夜 (albislol)   0.045467
# 889                    JonBams   0.045429
# 555                    BikeMan   0.044745
# 729                      BreaK   0.044177
# 766                  Alkaizerx   0.043716
# 849                   Spaceboy   0.043095
# 779                      Dyrus   0.042644
# 655                  gabepeixe   0.042177
# 985                   Surefour   0.041992
# 975               TommyKayLIVE   0.041637
# 648                 SheriffEli   0.041265
# 939                 Krayn_Live   0.040566
# 760                   Cryaotic   0.039762
# 940            西門夜說 (westdoor)   0.039641
# 824                    H0llyLP   0.039480
# 993          LAGTVMaximusBlack   0.039457
# 801                      CaMaK   0.039446
# 735                     CrReaM   0.039340
# 778            BananaSlamJamma   0.038957
# 910               RayNarvaezJr   0.038099
# 972                    HeyarTV   0.037036
# 859                  MANvsGAME   0.034875
# 891                OuterHeaven   0.032110
#
# Ranking Based on WPM Score (Entropy Weights):
#                        Channel  WPM Score
# 2                       Gaules   0.798561
# 10                TimTheTatman   0.548100
# 15              MontanaBlack88   0.541167
# 24               TheRealKnossi   0.516421
# 16                  sodapoppin   0.322980
# 84                     ZeratoR   0.305627
# 45                    Sardoche   0.299457
# 77                    Rainbow6   0.270524
# 74                    Symfuhny   0.221096
# 167                       wtcN   0.219384
# 171                Reborn_Live   0.205813
# 212                 AustinShow   0.199665
# 80               Trainwreckstv   0.185195
# 176            KendineMuzisyen   0.179912
# 55                       Gorgc   0.177434
# 114                     TeePee   0.176737
# 119                       aceu   0.173244
# 231                INSCOPE21TV   0.163309
# 179                  Greekgodx   0.161992
# 71                      forsen   0.157549
# 431                   JokerdTV   0.153873
# 339                     scoped   0.149132
# 218                      Aydan   0.148095
# 244                   Nadeshot   0.141321
# 168                      Anton   0.138370
# 63                      Quin69   0.137257
# 32                    MOONMOON   0.133992
# 568             ElcanaldeJoaco   0.133185
# 182                 Diegosaurs   0.122892
# 226                   mistermv   0.121657
# 65                    dasMEHDI   0.120228
# 988           CallMeCarsonLIVE   0.120016
# 126                   DreadzTV   0.119189
# 116                   Agraelus   0.117856
# 711                   Pimpeano   0.108844
# 140                     RATIRL   0.107593
# 353                    ELoTRiX   0.106525
# 821                Frankkaster   0.103363
# 927  Call of Duty (callofduty)   0.102724
# 295                   Homyatol   0.101450
# 89              AdmiralBulldog   0.098520
# 138                    Destiny   0.095881
# 404              limit_maximum   0.094066
# 70                       Vader   0.091955
# 249                   HoneyMad   0.088760
# 793                Sweet_Anita   0.088584
# 623                       zEkO   0.086711
# 416                  AlphaCast   0.086488
# 489                    Arteezy   0.085340
# 301                    Trick2g   0.085261
# 468                   Rammus53   0.085254
# 816                   Stewie2K   0.085094
# 145          木棉花官方頻道 (muse_tw)   0.083263
# 331                   MinosTV_   0.081410
# 526                  Skadoodle   0.081336
# 298                  boyMinORu   0.080950
# 660                      Datto   0.079981
# 498                       WOKE   0.079435
# 197                  Vinesauce   0.079384
# 137            老皮 (mobilmobil)   0.079222
# 481                     Kotton   0.078599
# 361               ALOHADANCETV   0.077373
# 374                   tarzaned   0.077234
# 679                     Tyceno   0.076866
# 273                  A_Seagull   0.076576
# 466                   1DrakoNz   0.076075
# 230                 melharucos   0.073733
# 329                       NymN   0.073542
# 254                   Sequisha   0.072877
# 524                      Mendo   0.072745
# 211                      B0aty   0.072570
# 184                    Nick28T   0.071204
# 624                   x6FlipiN   0.070427
# 606                  Peereira7   0.069975
# 495                      maxim   0.069745
# 752                     goncho   0.069041
# 666               GhostFreak66   0.068912
# 688                     Maghla   0.068617
# 867                   EFEUYGAC   0.068282
# 166                 RatedEpicz   0.068207
# 382                     adolfz   0.067641
# 583                    Worrun_   0.066568
# 280                 StaysafeTV   0.066269
# 674                    WARDELL   0.065916
# 573                 WeAreTheVR   0.065771
# 548                   Heelmike   0.065760
# 242                    mch_AGG   0.064647
# 480                      MoMaN   0.062258
# 248                 嬌兔 (zrush)   0.061642
# 826                RobertoCein   0.061333
# 434                   Jerma985   0.060991
# 296                    Grimmmz   0.060753
# 638               SovietWomble   0.060174
# 538                  ItsSlikeR   0.060061
# 774                      dizzy   0.059654
# 274                       koil   0.059251
# 783                  Kandyland   0.058620
# 810                    natalan   0.058535
# 508                    GTimeTV   0.057316
# 873                AnniTheDuck   0.056992
# 216                       Kyle   0.056799
# 882                  akagreenn   0.056693
# 368          AvoidingThePuddle   0.056209
# 453                   KabajiOW   0.056156
# 901                  innocents   0.056121
# 653                      Pengu   0.055833
# 484                   pijack11   0.053519
# 323                   singsing   0.052956
# 259              BarbarousKing   0.052726
# 286                      Shotz   0.051146
# 345                      sips_   0.050883
# 458                        cyr   0.050485
# 245                     buddha   0.049760
# 190                김도 (kimdoe)   0.049634
# 911                   Tanovich   0.049415
# 315                Distortion2   0.049280
# 270                   Aurateur   0.049156
# 592                      mang0   0.048896
# 467                     Pace22   0.048269
# 365                 RoyalPhunk   0.047492
# 307                   ANGRYPUG   0.047427
# 366                    Overpow   0.046537
# 727                  DougisRaw   0.045513
# 960                       Hype   0.045424
# 512               GrandPOObear   0.045099
# 762                 Sweatcicle   0.044664
# 519                   PsheroTV   0.043993
# 839                     Tourva   0.043973
# 387              The_Happy_Hob   0.042803
# 842             PainLivestream   0.042796
# 731                     Xposed   0.042504
# 381                       Kiwo   0.042352
# 421                     uhSnow   0.042290
# 717                    MaTaFe_   0.042144
# 796                   cellinrj   0.041745
# 848                     trihex   0.041671
# 673              Crocodyle_lol   0.041580
# 308                   MarcaoRX   0.040920
# 716                      THump   0.040869
# 406                  guit88man   0.040225
# 861                 foggedftw2   0.040171
# 705              超負荷 (sam1268)   0.039717
# 551           OfficialAndyPyro   0.039503
# 589                      iLame   0.039399
# 545                      Lasqa   0.039361
# 942               FantaBobShow   0.039240
# 831                      Limmy   0.039026
# 559                     Criken   0.038203
# 808                     chowh1   0.038169
# 751                       Vovo   0.037597
# 419                      PENTA   0.037578
# 643                    Broeki1   0.037077
# 698                  BRNWOWZK1   0.036218
# 620              龜狗 (gueigotv)   0.035975
# 744                    LobosJr   0.035257
# 909                      MuTeX   0.035143
# 742              Vargskelethor   0.035049
# 820                     Herdyn   0.034846
# 804                  roflgator   0.034512
# 914                 mandiocaa1   0.034158
# 790                      AkTep   0.034152
# 769                   Tanxlive   0.034048
# 807                    DieHahn   0.033284
# 491                     flamuu   0.032585
# 369                     Ko0416   0.032468
# 505            theRealShooKon3   0.032243
# 766                  Alkaizerx   0.031927
# 985                   Surefour   0.031876
# 581                  skill4ltu   0.031869
# 786            ProfessorBroman   0.031842
# 300                 BurkeBlack   0.031375
# 889                    JonBams   0.031236
# 683                 Drjayfisto   0.030475
# 729                      BreaK   0.030410
# 849                   Spaceboy   0.030100
# 503                   CuteDog_   0.030053
# 834                   CoconutB   0.029420
# 897                Ezekiel_III   0.029334
# 655                  gabepeixe   0.028668
# 760                   Cryaotic   0.028233
# 693          Zombie_Barricades   0.027738
# 910               RayNarvaezJr   0.027043
# 555                    BikeMan   0.026584
# 975               TommyKayLIVE   0.025843
# 778            BananaSlamJamma   0.024927
# 940            西門夜說 (westdoor)   0.024681
# 801                      CaMaK   0.024447
# 939                 Krayn_Live   0.023202
# 648                 SheriffEli   0.023163
# 824                    H0llyLP   0.022211
# 993          LAGTVMaximusBlack   0.021172
# 735                     CrReaM   0.019961
# 813             小夜夜 (albislol)   0.019808
# 891                OuterHeaven   0.017864
# 972                    HeyarTV   0.017302
# 859                  MANvsGAME   0.016622
# 779                      Dyrus   0.010386
# 42                    ROSHTEIN   0.000000
# 172                CasinoDaddy   0.000000
# 181                 ClassyBeef   0.000000
#
# Ranking Based on WASSPASS Score (Entropy Weights):
#                        Channel  WASSPASS Score
# 2                       Gaules        0.825239
# 10                TimTheTatman        0.574472
# 15              MontanaBlack88        0.574055
# 24               TheRealKnossi        0.556249
# 16                  sodapoppin        0.335918
# 84                     ZeratoR        0.330379
# 45                    Sardoche        0.302515
# 77                    Rainbow6        0.278874
# 171                Reborn_Live        0.242734
# 74                    Symfuhny        0.241960
# 212                 AustinShow        0.236186
# 167                       wtcN        0.233408
# 431                   JokerdTV        0.221222
# 119                       aceu        0.206236
# 176            KendineMuzisyen        0.195489
# 80               Trainwreckstv        0.192721
# 55                       Gorgc        0.183342
# 339                     scoped        0.181315
# 114                     TeePee        0.180569
# 231                INSCOPE21TV        0.179004
# 568             ElcanaldeJoaco        0.178400
# 179                  Greekgodx        0.172009
# 988           CallMeCarsonLIVE        0.170414
# 927  Call of Duty (callofduty)        0.169990
# 71                      forsen        0.166278
# 218                      Aydan        0.160602
# 244                   Nadeshot        0.157260
# 168                      Anton        0.156672
# 32                    MOONMOON        0.151884
# 711                   Pimpeano        0.148439
# 63                      Quin69        0.147218
# 126                   DreadzTV        0.133093
# 65                    dasMEHDI        0.131752
# 182                 Diegosaurs        0.129718
# 116                   Agraelus        0.126383
# 226                   mistermv        0.125626
# 821                Frankkaster        0.120915
# 140                     RATIRL        0.120074
# 489                    Arteezy        0.119396
# 353                    ELoTRiX        0.118619
# 404              limit_maximum        0.114823
# 793                Sweet_Anita        0.114769
# 89              AdmiralBulldog        0.112506
# 295                   Homyatol        0.109228
# 70                       Vader        0.107302
# 145          木棉花官方頻道 (muse_tw)        0.105125
# 623                       zEkO        0.104365
# 42                    ROSHTEIN        0.104088
# 138                    Destiny        0.101926
# 468                   Rammus53        0.101077
# 816                   Stewie2K        0.099511
# 249                   HoneyMad        0.096422
# 137            老皮 (mobilmobil)        0.094125
# 660                      Datto        0.092449
# 679                     Tyceno        0.091683
# 242                    mch_AGG        0.091290
# 416                  AlphaCast        0.090688
# 606                  Peereira7        0.090615
# 331                   MinosTV_        0.090323
# 301                    Trick2g        0.089653
# 526                  Skadoodle        0.089446
# 666               GhostFreak66        0.088850
# 298                  boyMinORu        0.088763
# 826                RobertoCein        0.087451
# 466                   1DrakoNz        0.087385
# 810                    natalan        0.087099
# 197                  Vinesauce        0.086873
# 498                       WOKE        0.086231
# 481                     Kotton        0.085751
# 374                   tarzaned        0.084669
# 230                 melharucos        0.083860
# 867                   EFEUYGAC        0.083690
# 361               ALOHADANCETV        0.082773
# 674                    WARDELL        0.081753
# 273                  A_Seagull        0.081609
# 184                    Nick28T        0.079719
# 211                      B0aty        0.079549
# 524                      Mendo        0.079524
# 752                     goncho        0.079149
# 254                   Sequisha        0.079094
# 688                     Maghla        0.078973
# 329                       NymN        0.078314
# 166                 RatedEpicz        0.077873
# 624                   x6FlipiN        0.077347
# 382                     adolfz        0.076589
# 548                   Heelmike        0.075564
# 495                      maxim        0.074387
# 583                    Worrun_        0.073273
# 280                 StaysafeTV        0.072313
# 873                AnniTheDuck        0.072291
# 248                 嬌兔 (zrush)        0.071589
# 901                  innocents        0.071517
# 638               SovietWomble        0.071423
# 783                  Kandyland        0.071117
# 573                 WeAreTheVR        0.069998
# 480                      MoMaN        0.069858
# 653                      Pengu        0.069633
# 296                    Grimmmz        0.068956
# 508                    GTimeTV        0.068833
# 538                  ItsSlikeR        0.067558
# 434                   Jerma985        0.067425
# 190                김도 (kimdoe)        0.067172
# 274                       koil        0.066704
# 216                       Kyle        0.066467
# 774                      dizzy        0.064777
# 484                   pijack11        0.064222
# 882                  akagreenn        0.062168
# 911                   Tanovich        0.062121
# 368          AvoidingThePuddle        0.062086
# 259              BarbarousKing        0.061907
# 453                   KabajiOW        0.061142
# 323                   singsing        0.059891
# 286                      Shotz        0.059360
# 245                     buddha        0.059311
# 308                   MarcaoRX        0.059252
# 345                      sips_        0.058642
# 839                     Tourva        0.058364
# 270                   Aurateur        0.058315
# 315                Distortion2        0.057568
# 467                     Pace22        0.057437
# 458                        cyr        0.056808
# 307                   ANGRYPUG        0.056677
# 698                  BRNWOWZK1        0.056663
# 366                    Overpow        0.055715
# 592                      mang0        0.055641
# 365                 RoyalPhunk        0.054040
# 727                  DougisRaw        0.053859
# 762                 Sweatcicle        0.053772
# 381                       Kiwo        0.053618
# 519                   PsheroTV        0.052796
# 731                     Xposed        0.052669
# 960                       Hype        0.051850
# 551           OfficialAndyPyro        0.051801
# 717                    MaTaFe_        0.051671
# 589                      iLame        0.050843
# 512               GrandPOObear        0.050300
# 181                 ClassyBeef        0.050246
# 387              The_Happy_Hob        0.049929
# 406                  guit88man        0.049905
# 796                   cellinrj        0.049847
# 421                     uhSnow        0.049121
# 716                      THump        0.048960
# 848                     trihex        0.048571
# 831                      Limmy        0.048541
# 369                     Ko0416        0.048486
# 842             PainLivestream        0.048418
# 861                 foggedftw2        0.048188
# 705              超負荷 (sam1268)        0.047792
# 673              Crocodyle_lol        0.047533
# 751                       Vovo        0.046893
# 808                     chowh1        0.046611
# 909                      MuTeX        0.045991
# 545                      Lasqa        0.045542
# 419                      PENTA        0.045107
# 942               FantaBobShow        0.044960
# 820                     Herdyn        0.044642
# 300                 BurkeBlack        0.044505
# 643                    Broeki1        0.044368
# 559                     Criken        0.044222
# 620              龜狗 (gueigotv)        0.043525
# 769                   Tanxlive        0.043372
# 744                    LobosJr        0.041585
# 914                 mandiocaa1        0.041510
# 742              Vargskelethor        0.041377
# 505            theRealShooKon3        0.041332
# 503                   CuteDog_        0.041160
# 804                  roflgator        0.040830
# 693          Zombie_Barricades        0.040804
# 581                  skill4ltu        0.040775
# 491                     flamuu        0.040670
# 683                 Drjayfisto        0.040444
# 790                      AkTep        0.040228
# 807                    DieHahn        0.039922
# 786            ProfessorBroman        0.039896
# 172                CasinoDaddy        0.038424
# 889                    JonBams        0.038333
# 897                Ezekiel_III        0.037823
# 766                  Alkaizerx        0.037822
# 834                   CoconutB        0.037487
# 729                      BreaK        0.037293
# 985                   Surefour        0.036934
# 849                   Spaceboy        0.036597
# 555                    BikeMan        0.035665
# 655                  gabepeixe        0.035423
# 760                   Cryaotic        0.033998
# 975               TommyKayLIVE        0.033740
# 813             小夜夜 (albislol)        0.032638
# 910               RayNarvaezJr        0.032571
# 648                 SheriffEli        0.032214
# 940            西門夜說 (westdoor)        0.032161
# 801                      CaMaK        0.031947
# 778            BananaSlamJamma        0.031942
# 939                 Krayn_Live        0.031884
# 824                    H0llyLP        0.030846
# 993          LAGTVMaximusBlack        0.030315
# 735                     CrReaM        0.029651
# 972                    HeyarTV        0.027169
# 779                      Dyrus        0.026515
# 859                  MANvsGAME        0.025748
# 891                OuterHeaven        0.024987
# C:\Users\amine\AppData\Local\Temp\ipykernel_20636\2698668945.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["WSM Score"] = wsm_scores
# C:\Users\amine\AppData\Local\Temp\ipykernel_20636\2698668945.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["WPM Score"] = wpm_scores

# %% [markdown]
# #### 2- TOPSIS

# %%
# Define max/min criteria 
criteria_types = ['max', 'max', 'max', 'max', 'max', 'max', 'max']

# Given Entropy Weights
entropy_weights = np.array([0.21041816, 0.14298389, 0.25862418, 0.16473849, 
                            0.16506985, 0.05258346, 0.00558197])

# Convert Partnered (True/False) to numeric
df_final["Partnered"] = df_final["Partnered"].astype(int)

# Extract decision matrix (X) and Channel names
X = df_final[criteria].values
channels = df_final["Channel"].values

# Step 1: Normalize the decision matrix
norms = np.linalg.norm(X, axis=0)
X_norm = X / norms

# Step 2: Adjust for min/max criteria
for i, ctype in enumerate(criteria_types):
    if ctype == 'min':  
        X_norm[:, i] = 1 - X_norm[:, i]  # Flip values for minimization

# Step 3: Multiply by Entropy Weights
X_weighted = X_norm * entropy_weights

# Step 4: Compute ideal and anti-ideal solutions
ideal_solution = np.max(X_weighted, axis=0)   # Best values
anti_ideal_solution = np.min(X_weighted, axis=0)  # Worst values

# Step 5: Compute distances to ideal and anti-ideal solutions
dist_ideal = np.sqrt(np.sum((X_weighted - ideal_solution) ** 2, axis=1))
dist_anti_ideal = np.sqrt(np.sum((X_weighted - anti_ideal_solution) ** 2, axis=1))

# Step 6: Compute TOPSIS scores
topsis_score = dist_anti_ideal / (dist_ideal + dist_anti_ideal)

# Step 7: Rank alternatives
df_final["TOPSIS_Score"] = topsis_score
df_final["Rank"] = df_final["TOPSIS_Score"].rank(ascending=False)

# Step 8: Sort by rank
df_final_sorted = df_final.sort_values(by="Rank")

# Display all rows
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns (if needed)
pd.set_option('display.expand_frame_repr', False)  # Prevent line wrapping

# Print full results
print("\nTOPSIS Results (Ranked) using Entropy Weights:")
print(df_final_sorted[["Channel", "TOPSIS_Score", "Rank"]])
# Out:
# TOPSIS Results (Ranked) using Entropy Weights:
#                        Channel  TOPSIS_Score   Rank
# 2                       Gaules      0.803342    1.0
# 24               TheRealKnossi      0.554518    2.0
# 15              MontanaBlack88      0.534056    3.0
# 10                TimTheTatman      0.527581    4.0
# 84                     ZeratoR      0.409998    5.0
# 431                   JokerdTV      0.400846    6.0
# 16                  sodapoppin      0.349302    7.0
# 45                    Sardoche      0.304340    8.0
# 927  Call of Duty (callofduty)      0.289279    9.0
# 77                    Rainbow6      0.278356   10.0
# 212                 AustinShow      0.261847   11.0
# 171                Reborn_Live      0.252579   12.0
# 74                    Symfuhny      0.234222   13.0
# 167                       wtcN      0.225226   14.0
# 119                       aceu      0.221134   15.0
# 568             ElcanaldeJoaco      0.217668   16.0
# 988           CallMeCarsonLIVE      0.217514   17.0
# 168                      Anton      0.211373   18.0
# 339                     scoped      0.206800   19.0
# 42                    ROSHTEIN      0.195259   20.0
# 711                   Pimpeano      0.187774   21.0
# 176            KendineMuzisyen      0.185695   22.0
# 404              limit_maximum      0.184572   23.0
# 55                       Gorgc      0.176799   24.0
# 489                    Arteezy      0.176776   25.0
# 231                INSCOPE21TV      0.173677   26.0
# 80               Trainwreckstv      0.170666   27.0
# 32                    MOONMOON      0.169672   28.0
# 114                     TeePee      0.168193   29.0
# 71                      forsen      0.158737   30.0
# 179                  Greekgodx      0.156196   31.0
# 126                   DreadzTV      0.153342   32.0
# 244                   Nadeshot      0.153157   33.0
# 218                      Aydan      0.151562   34.0
# 63                      Quin69      0.146174   35.0
# 793                Sweet_Anita      0.141732   36.0
# 666               GhostFreak66      0.141501   37.0
# 65                    dasMEHDI      0.130995   38.0
# 821                Frankkaster      0.129158   39.0
# 660                      Datto      0.125742   40.0
# 810                    natalan      0.123386   41.0
# 116                   Agraelus      0.116919   42.0
# 89              AdmiralBulldog      0.116559   43.0
# 826                RobertoCein      0.115054   44.0
# 70                       Vader      0.113445   45.0
# 353                    ELoTRiX      0.112566   46.0
# 623                       zEkO      0.112356   47.0
# 226                   mistermv      0.110041   48.0
# 182                 Diegosaurs      0.109992   49.0
# 140                     RATIRL      0.107924   50.0
# 137            老皮 (mobilmobil)      0.104496   51.0
# 468                   Rammus53      0.103671   52.0
# 606                  Peereira7      0.102996   53.0
# 816                   Stewie2K      0.101209   54.0
# 679                     Tyceno      0.096813   55.0
# 145          木棉花官方頻道 (muse_tw)      0.096556   56.0
# 295                   Homyatol      0.095167   57.0
# 481                     Kotton      0.094813   58.0
# 249                   HoneyMad      0.091219   59.0
# 867                   EFEUYGAC      0.090119   60.0
# 498                       WOKE      0.087989   61.0
# 242                    mch_AGG      0.087977   62.0
# 674                    WARDELL      0.085273   63.0
# 298                  boyMinORu      0.084255   64.0
# 230                 melharucos      0.083902   65.0
# 138                    Destiny      0.082570   66.0
# 466                   1DrakoNz      0.080759   67.0
# 181                 ClassyBeef      0.080177   68.0
# 526                  Skadoodle      0.080129   69.0
# 901                  innocents      0.079873   70.0
# 873                AnniTheDuck      0.079194   71.0
# 197                  Vinesauce      0.076728   72.0
# 190                김도 (kimdoe)      0.075989   73.0
# 752                     goncho      0.075407   74.0
# 688                     Maghla      0.074577   75.0
# 416                  AlphaCast      0.074064   76.0
# 331                   MinosTV_      0.073860   77.0
# 653                      Pengu      0.071950   78.0
# 783                  Kandyland      0.071405   79.0
# 361               ALOHADANCETV      0.071280   80.0
# 583                    Worrun_      0.071049   81.0
# 374                   tarzaned      0.070677   82.0
# 301                    Trick2g      0.070499   83.0
# 273                  A_Seagull      0.068432   84.0
# 638               SovietWomble      0.068043   85.0
# 548                   Heelmike      0.067663   86.0
# 524                      Mendo      0.066798   87.0
# 382                     adolfz      0.066796   88.0
# 624                   x6FlipiN      0.066537   89.0
# 248                 嬌兔 (zrush)      0.066482   90.0
# 211                      B0aty      0.065418   91.0
# 166                 RatedEpicz      0.064443   92.0
# 911                   Tanovich      0.064046   93.0
# 184                    Nick28T      0.063417   94.0
# 172                CasinoDaddy      0.061914   95.0
# 329                       NymN      0.059952   96.0
# 254                   Sequisha      0.059604   97.0
# 839                     Tourva      0.059475   98.0
# 495                      maxim      0.058023   99.0
# 508                    GTimeTV      0.057192  100.0
# 573                 WeAreTheVR      0.056376  101.0
# 434                   Jerma985      0.056051  102.0
# 698                  BRNWOWZK1      0.055945  103.0
# 296                    Grimmmz      0.055580  104.0
# 480                      MoMaN      0.055139  105.0
# 280                 StaysafeTV      0.054360  106.0
# 538                  ItsSlikeR      0.054184  107.0
# 308                   MarcaoRX      0.053879  108.0
# 216                       Kyle      0.053834  109.0
# 369                     Ko0416      0.053210  110.0
# 484                   pijack11      0.053043  111.0
# 774                      dizzy      0.052097  112.0
# 274                       koil      0.051825  113.0
# 882                  akagreenn      0.050864  114.0
# 245                     buddha      0.049751  115.0
# 551           OfficialAndyPyro      0.048661  116.0
# 368          AvoidingThePuddle      0.047602  117.0
# 259              BarbarousKing      0.047375  118.0
# 705              超負荷 (sam1268)      0.046464  119.0
# 366                    Overpow      0.046269  120.0
# 270                   Aurateur      0.046041  121.0
# 589                      iLame      0.045921  122.0
# 731                     Xposed      0.045829  123.0
# 453                   KabajiOW      0.044971  124.0
# 323                   singsing      0.044780  125.0
# 286                      Shotz      0.044416  126.0
# 592                      mang0      0.044090  127.0
# 345                      sips_      0.043641  128.0
# 727                  DougisRaw      0.043627  129.0
# 762                 Sweatcicle      0.043385  130.0
# 467                     Pace22      0.043015  131.0
# 406                  guit88man      0.042398  132.0
# 315                Distortion2      0.042323  133.0
# 831                      Limmy      0.042081  134.0
# 307                   ANGRYPUG      0.042013  135.0
# 381                       Kiwo      0.041838  136.0
# 458                        cyr      0.040996  137.0
# 848                     trihex      0.040512  138.0
# 914                 mandiocaa1      0.040385  139.0
# 960                       Hype      0.040157  140.0
# 365                 RoyalPhunk      0.039977  141.0
# 796                   cellinrj      0.039956  142.0
# 717                    MaTaFe_      0.039837  143.0
# 300                 BurkeBlack      0.039467  144.0
# 909                      MuTeX      0.039121  145.0
# 716                      THump      0.038353  146.0
# 519                   PsheroTV      0.038234  147.0
# 861                 foggedftw2      0.037190  148.0
# 421                     uhSnow      0.036273  149.0
# 387              The_Happy_Hob      0.036201  150.0
# 820                     Herdyn      0.035963  151.0
# 751                       Vovo      0.035417  152.0
# 769                   Tanxlive      0.034950  153.0
# 693          Zombie_Barricades      0.034827  154.0
# 842             PainLivestream      0.034729  155.0
# 545                      Lasqa      0.034317  156.0
# 808                     chowh1      0.034227  157.0
# 512               GrandPOObear      0.033763  158.0
# 897                Ezekiel_III      0.032602  159.0
# 942               FantaBobShow      0.032352  160.0
# 503                   CuteDog_      0.032301  161.0
# 683                 Drjayfisto      0.032077  162.0
# 673              Crocodyle_lol      0.032029  163.0
# 620              龜狗 (gueigotv)      0.031781  164.0
# 643                    Broeki1      0.031485  165.0
# 419                      PENTA      0.031244  166.0
# 813             小夜夜 (albislol)      0.030795  167.0
# 742              Vargskelethor      0.030419  168.0
# 786            ProfessorBroman      0.029005  169.0
# 581                  skill4ltu      0.028865  170.0
# 505            theRealShooKon3      0.028854  171.0
# 559                     Criken      0.028782  172.0
# 804                  roflgator      0.028295  173.0
# 744                    LobosJr      0.028152  174.0
# 491                     flamuu      0.027465  175.0
# 889                    JonBams      0.026901  176.0
# 779                      Dyrus      0.026202  177.0
# 790                      AkTep      0.026162  178.0
# 834                   CoconutB      0.025769  179.0
# 807                    DieHahn      0.025570  180.0
# 555                    BikeMan      0.025412  181.0
# 985                   Surefour      0.024969  182.0
# 766                  Alkaizerx      0.024902  183.0
# 729                      BreaK      0.024729  184.0
# 939                 Krayn_Live      0.024088  185.0
# 849                   Spaceboy      0.023710  186.0
# 975               TommyKayLIVE      0.023343  187.0
# 940            西門夜說 (westdoor)      0.023297  188.0
# 993          LAGTVMaximusBlack      0.023270  189.0
# 648                 SheriffEli      0.022630  190.0
# 655                  gabepeixe      0.022258  191.0
# 735                     CrReaM      0.022128  192.0
# 824                    H0llyLP      0.022075  193.0
# 801                      CaMaK      0.021994  194.0
# 972                    HeyarTV      0.021790  195.0
# 760                   Cryaotic      0.020406  196.0
# 859                  MANvsGAME      0.020012  197.0
# 778            BananaSlamJamma      0.019635  198.0
# 910               RayNarvaezJr      0.019127  199.0
# 891                OuterHeaven      0.015711  200.0

# %% [markdown]
# #### 3- PROMETHEE I and PROMETHEE II

# %%
# Extract relevant data
df_final = top_mature_streamers[["Channel"] + criteria]
matrix = df_final[criteria].values  # Convert to NumPy array
n, m = matrix.shape

# Define AHP weights
weights = np.array([0.21041816, 0.14298389, 0.25862418, 0.16473849, 0.16506985, 0.05258346, 0.00558197])
weights /= np.sum(weights)  # Normalize weights

# Define criteria types (1 = maximization, adjust if needed)
criteria_types = np.ones(m, dtype=int)  # Assuming all are beneficial

# PROMETHEE Functions
def normalize_promethee(matrix, criteria_types):
    """Normalize the decision matrix for PROMETHEE."""
    n, m = matrix.shape
    normalized_matrix = np.zeros((n, m), dtype=float)
    
    for j in range(m):
        col_min, col_max = np.min(matrix[:, j]), np.max(matrix[:, j])
        if col_max == col_min:  # Avoid division by zero
            normalized_matrix[:, j] = 1
        else:
            normalized_matrix[:, j] = (matrix[:, j] - col_min) / (col_max - col_min)
    
    return normalized_matrix

def compute_promethee(matrix, criteria_types, weights):
    """Compute PROMETHEE I (partial ranking) and PROMETHEE II (complete ranking)."""
    n, m = matrix.shape
    normalized_matrix = normalize_promethee(matrix, criteria_types)

    # Compute pairwise preference differences
    pairwise_differences = np.zeros((n, n, m))
    for i in range(n):
        for j in range(n):
            pairwise_differences[i, j, :] = normalized_matrix[i, :] - normalized_matrix[j, :]

    # Compute preference function Pj(a,b)
    preference_matrix = np.maximum(pairwise_differences, 0)

    # Weighted preference matrix
    weighted_preference_matrix = np.multiply(preference_matrix, weights)

    # Priority matrix
    priority_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            priority_matrix[i, j] = np.sum(weighted_preference_matrix[i, j, :])

    # Compute Phi+ (positive flow) and Phi- (negative flow)
    phi_plus = np.sum(priority_matrix, axis=1) / (n - 1)
    phi_minus = np.sum(priority_matrix, axis=0) / (n - 1)
    phi_net = phi_plus - phi_minus

    # -----------------------------
    # PROMETHEE I (Partial Ranking)
    # -----------------------------
    ranking_df = pd.DataFrame({
        "Channel": df_final["Channel"],
        "Phi+": phi_plus,
        "Phi-": phi_minus
    }).sort_values(by="Phi+", ascending=False).reset_index(drop=True)

    # Group alternatives based on Phi+ and Phi-
    ranking_groups = {}
    for i in range(n):
        alternative = ranking_df.iloc[i]["Channel"]
        phi_p, phi_m = ranking_df.iloc[i]["Phi+"], ranking_df.iloc[i]["Phi-"]

        # Define relationships
        rank_label = f"Phi+={phi_p:.3f}, Phi-={phi_m:.3f}"
        if rank_label not in ranking_groups:
            ranking_groups[rank_label] = []
        ranking_groups[rank_label].append(alternative)

    # -----------------------------
    # PROMETHEE II (Complete Ranking)
    # -----------------------------
    ranking_df["Phi_Net"] = phi_net
    ranking_df = ranking_df.sort_values(by="Phi_Net", ascending=False).reset_index(drop=True)

    return normalized_matrix, priority_matrix, phi_plus, phi_minus, phi_net, ranking_groups, ranking_df

# Compute PROMETHEE results
normalized_matrix, priority_matrix, phi_plus, phi_minus, phi_net, ranking_groups, ranking_df = compute_promethee(matrix, criteria_types, weights)

# Display results
print("\nPROMETHEE I Ranking: (AHP WEIGHTS)")
for rank, alternatives in ranking_groups.items():
    print(f"{rank} -> {', '.join(alternatives)}")

# Show ranking dataframe
print("\nPROMETHEE II Ranking: (AHP WEIGHTS)")
print(ranking_df)  # Display top-ranked streamers
# Out:
# PROMETHEE I Ranking: (AHP WEIGHTS)
# Phi+=0.758, Phi-=0.003 -> Gaules
# Phi+=0.515, Phi-=0.009 -> MontanaBlack88
# Phi+=0.506, Phi-=0.007 -> TimTheTatman
# Phi+=0.504, Phi-=0.010 -> TheRealKnossi
# Phi+=0.270, Phi-=0.019 -> ZeratoR
# Phi+=0.262, Phi-=0.017 -> sodapoppin
# Phi+=0.217, Phi-=0.035 -> JokerdTV
# Phi+=0.215, Phi-=0.015 -> Sardoche
# Phi+=0.199, Phi-=0.018 -> Rainbow6
# Phi+=0.198, Phi-=0.025 -> Reborn_Live
# Phi+=0.195, Phi-=0.027 -> AustinShow
# Phi+=0.180, Phi-=0.049 -> Call of Duty (callofduty)
# Phi+=0.174, Phi-=0.018 -> Symfuhny
# Phi+=0.162, Phi-=0.021 -> wtcN
# Phi+=0.155, Phi-=0.022 -> aceu
# Phi+=0.151, Phi-=0.037 -> CallMeCarsonLIVE
# Phi+=0.150, Phi-=0.034 -> ElcanaldeJoaco
# Phi+=0.135, Phi-=0.029 -> scoped
# Phi+=0.131, Phi-=0.029 -> ROSHTEIN
# Phi+=0.130, Phi-=0.025 -> KendineMuzisyen
# Phi+=0.119, Phi-=0.038 -> Pimpeano
# Phi+=0.115, Phi-=0.022 -> Trainwreckstv
# Phi+=0.115, Phi-=0.027 -> INSCOPE21TV
# Phi+=0.110, Phi-=0.027 -> Gorgc
# Phi+=0.103, Phi-=0.025 -> TeePee
# Phi+=0.102, Phi-=0.034 -> Anton
# Phi+=0.101, Phi-=0.026 -> Greekgodx
# Phi+=0.098, Phi-=0.029 -> forsen
# Phi+=0.098, Phi-=0.034 -> MOONMOON
# Phi+=0.097, Phi-=0.031 -> Nadeshot
# Phi+=0.096, Phi-=0.049 -> Arteezy
# Phi+=0.092, Phi-=0.027 -> Aydan
# Phi+=0.084, Phi-=0.033 -> Quin69
# Phi+=0.079, Phi-=0.039 -> DreadzTV
# Phi+=0.075, Phi-=0.047 -> limit_maximum
# Phi+=0.074, Phi-=0.041 -> Sweet_Anita
# Phi+=0.073, Phi-=0.037 -> dasMEHDI
# Phi+=0.071, Phi-=0.040 -> Frankkaster
# Phi+=0.064, Phi-=0.044 -> 木棉花官方頻道 (muse_tw)
# Phi+=0.062, Phi-=0.035 -> Agraelus
# Phi+=0.061, Phi-=0.032 -> Diegosaurs
# Phi+=0.061, Phi-=0.038 -> ELoTRiX
# Phi+=0.060, Phi-=0.050 -> mch_AGG
# Phi+=0.059, Phi-=0.040 -> AdmiralBulldog
# Phi+=0.059, Phi-=0.034 -> RATIRL
# Phi+=0.059, Phi-=0.037 -> mistermv
# Phi+=0.058, Phi-=0.050 -> natalan
# Phi+=0.057, Phi-=0.042 -> Vader
# Phi+=0.056, Phi-=0.042 -> zEkO
# Phi+=0.054, Phi-=0.053 -> GhostFreak66
# Phi+=0.053, Phi-=0.048 -> RobertoCein
# Phi+=0.051, Phi-=0.045 -> Stewie2K
# Phi+=0.049, Phi-=0.040 -> Rammus53
# Phi+=0.048, Phi-=0.046 -> 老皮 (mobilmobil)
# Phi+=0.048, Phi-=0.038 -> Homyatol
# Phi+=0.047, Phi-=0.050 -> Datto
# Phi+=0.047, Phi-=0.044 -> Peereira7
# Phi+=0.046, Phi-=0.048 -> Tyceno
# Phi+=0.042, Phi-=0.050 -> ClassyBeef
# Phi+=0.042, Phi-=0.045 -> HoneyMad
# Phi+=0.040, Phi-=0.039 -> Destiny
# Phi+=0.040, Phi-=0.049 -> EFEUYGAC
# Phi+=0.036, Phi-=0.047 -> WARDELL
# Phi+=0.035, Phi-=0.050 -> Kotton
# Phi+=0.034, Phi-=0.050 -> WOKE
# Phi+=0.034, Phi-=0.044 -> 1DrakoNz, Skadoodle
# Phi+=0.034, Phi-=0.045 -> boyMinORu
# Phi+=0.033, Phi-=0.042 -> MinosTV_
# Phi+=0.033, Phi-=0.047 -> melharucos
# Phi+=0.033, Phi-=0.046 -> Vinesauce
# Phi+=0.031, Phi-=0.052 -> AnniTheDuck, innocents
# Phi+=0.031, Phi-=0.062 -> BRNWOWZK1
# Phi+=0.031, Phi-=0.054 -> 김도 (kimdoe)
# Phi+=0.031, Phi-=0.044 -> AlphaCast
# Phi+=0.030, Phi-=0.061 -> CasinoDaddy
# Phi+=0.029, Phi-=0.049 -> goncho
# Phi+=0.029, Phi-=0.045 -> tarzaned
# Phi+=0.029, Phi-=0.043 -> Trick2g
# Phi+=0.029, Phi-=0.060 -> MarcaoRX
# Phi+=0.029, Phi-=0.048 -> Maghla
# Phi+=0.028, Phi-=0.048 -> ALOHADANCETV
# Phi+=0.027, Phi-=0.048 -> RatedEpicz, A_Seagull
# Phi+=0.027, Phi-=0.050 -> adolfz
# Phi+=0.027, Phi-=0.047 -> Nick28T
# Phi+=0.027, Phi-=0.052 -> Pengu
# Phi+=0.026, Phi-=0.051 -> Kandyland
# Phi+=0.026, Phi-=0.048 -> B0aty
# Phi+=0.025, Phi-=0.049 -> Heelmike, x6FlipiN
# Phi+=0.025, Phi-=0.051 -> SovietWomble
# Phi+=0.025, Phi-=0.047 -> Mendo
# Phi+=0.024, Phi-=0.051 -> 嬌兔 (zrush)
# Phi+=0.024, Phi-=0.052 -> Worrun_
# Phi+=0.024, Phi-=0.047 -> Sequisha
# Phi+=0.023, Phi-=0.051 -> GTimeTV
# Phi+=0.022, Phi-=0.047 -> NymN
# Phi+=0.022, Phi-=0.055 -> Tanovich
# Phi+=0.021, Phi-=0.052 -> Grimmmz
# Phi+=0.020, Phi-=0.050 -> maxim
# Phi+=0.020, Phi-=0.056 -> Tourva
# Phi+=0.020, Phi-=0.052 -> Kyle
# Phi+=0.020, Phi-=0.063 -> Ko0416
# Phi+=0.019, Phi-=0.054 -> Jerma985
# Phi+=0.019, Phi-=0.050 -> MoMaN
# Phi+=0.019, Phi-=0.049 -> StaysafeTV
# Phi+=0.018, Phi-=0.052 -> pijack11, koil, WeAreTheVR
# Phi+=0.018, Phi-=0.055 -> BarbarousKing
# Phi+=0.018, Phi-=0.062 -> OfficialAndyPyro
# Phi+=0.018, Phi-=0.051 -> ItsSlikeR
# Phi+=0.017, Phi-=0.061 -> Kiwo
# Phi+=0.016, Phi-=0.056 -> buddha
# Phi+=0.016, Phi-=0.055 -> dizzy
# Phi+=0.016, Phi-=0.057 -> Aurateur
# Phi+=0.015, Phi-=0.056 -> akagreenn
# Phi+=0.015, Phi-=0.057 -> ANGRYPUG
# Phi+=0.015, Phi-=0.055 -> AvoidingThePuddle
# Phi+=0.014, Phi-=0.055 -> Shotz
# Phi+=0.014, Phi-=0.058 -> Overpow
# Phi+=0.014, Phi-=0.056 -> Distortion2, Pace22
# Phi+=0.014, Phi-=0.060 -> iLame
# Phi+=0.014, Phi-=0.069 -> Zombie_Barricades
# Phi+=0.013, Phi-=0.055 -> singsing, sips_, KabajiOW
# Phi+=0.013, Phi-=0.060 -> DougisRaw
# Phi+=0.013, Phi-=0.059 -> Xposed, Sweatcicle
# Phi+=0.013, Phi-=0.064 -> BurkeBlack
# Phi+=0.013, Phi-=0.065 -> 超負荷 (sam1268)
# Phi+=0.012, Phi-=0.059 -> mang0, PsheroTV, MaTaFe_
# Phi+=0.012, Phi-=0.061 -> guit88man
# Phi+=0.012, Phi-=0.057 -> cyr
# Phi+=0.011, Phi-=0.063 -> MuTeX
# Phi+=0.011, Phi-=0.068 -> CuteDog_
# Phi+=0.011, Phi-=0.061 -> Limmy
# Phi+=0.011, Phi-=0.074 -> 小夜夜 (albislol)
# Phi+=0.011, Phi-=0.058 -> RoyalPhunk
# Phi+=0.010, Phi-=0.070 -> mandiocaa1
# Phi+=0.010, Phi-=0.060 -> cellinrj
# Phi+=0.010, Phi-=0.063 -> trihex
# Phi+=0.009, Phi-=0.062 -> Vovo
# Phi+=0.009, Phi-=0.061 -> THump, uhSnow, foggedftw2
# Phi+=0.009, Phi-=0.060 -> Hype, The_Happy_Hob
# Phi+=0.009, Phi-=0.065 -> Tanxlive
# Phi+=0.008, Phi-=0.062 -> chowh1
# Phi+=0.008, Phi-=0.063 -> Herdyn
# Phi+=0.008, Phi-=0.066 -> Drjayfisto, theRealShooKon3
# Phi+=0.007, Phi-=0.060 -> GrandPOObear
# Phi+=0.007, Phi-=0.062 -> PainLivestream
# Phi+=0.007, Phi-=0.063 -> PENTA
# Phi+=0.007, Phi-=0.064 -> Lasqa, Broeki1, 龜狗 (gueigotv)
# Phi+=0.007, Phi-=0.068 -> ProfessorBroman
# Phi+=0.006, Phi-=0.061 -> Crocodyle_lol
# Phi+=0.006, Phi-=0.065 -> skill4ltu
# Phi+=0.006, Phi-=0.069 -> Ezekiel_III
# Phi+=0.006, Phi-=0.064 -> FantaBobShow
# Phi+=0.006, Phi-=0.067 -> Vargskelethor
# Phi+=0.006, Phi-=0.066 -> flamuu
# Phi+=0.006, Phi-=0.075 -> LAGTVMaximusBlack
# Phi+=0.005, Phi-=0.064 -> Criken
# Phi+=0.005, Phi-=0.069 -> BikeMan
# Phi+=0.005, Phi-=0.067 -> roflgator
# Phi+=0.005, Phi-=0.071 -> Dyrus
# Phi+=0.005, Phi-=0.066 -> LobosJr
# Phi+=0.005, Phi-=0.077 -> HeyarTV
# Phi+=0.005, Phi-=0.068 -> CoconutB
# Phi+=0.005, Phi-=0.072 -> SheriffEli
# Phi+=0.004, Phi-=0.068 -> JonBams, BreaK
# Phi+=0.004, Phi-=0.073 -> Krayn_Live, H0llyLP
# Phi+=0.004, Phi-=0.074 -> CrReaM
# Phi+=0.004, Phi-=0.067 -> DieHahn
# Phi+=0.004, Phi-=0.066 -> AkTep
# Phi+=0.004, Phi-=0.070 -> Spaceboy, Surefour
# Phi+=0.004, Phi-=0.069 -> Alkaizerx
# Phi+=0.004, Phi-=0.071 -> TommyKayLIVE
# Phi+=0.003, Phi-=0.070 -> gabepeixe
# Phi+=0.003, Phi-=0.072 -> 西門夜說 (westdoor), CaMaK
# Phi+=0.003, Phi-=0.073 -> BananaSlamJamma
# Phi+=0.002, Phi-=0.071 -> Cryaotic
# Phi+=0.002, Phi-=0.076 -> MANvsGAME
# Phi+=0.002, Phi-=0.073 -> RayNarvaezJr
# Phi+=0.002, Phi-=0.078 -> OuterHeaven
#
# PROMETHEE II Ranking: (AHP WEIGHTS)
#                        Channel      Phi+      Phi-   Phi_Net
# 0                   sodapoppin  0.262484  0.017220  0.754774
# 1               MontanaBlack88  0.514904  0.008991  0.505913
# 2                       Gaules  0.757555  0.002782  0.499573
# 3             CallMeCarsonLIVE  0.150673  0.037104  0.494239
# 4                        Anton  0.101966  0.034081  0.250567
# 5                 TimTheTatman  0.506185  0.006612  0.245265
# 6                limit_maximum  0.075240  0.047327  0.200408
# 7               PainLivestream  0.007287  0.061934  0.182538
# 8                     Sardoche  0.214935  0.014527  0.181677
# 9                      ELoTRiX  0.060622  0.037726  0.173738
# 10                    MOONMOON  0.097659  0.034190  0.167285
# 11               TheRealKnossi  0.504019  0.009780  0.156598
# 12                     ZeratoR  0.269799  0.019232  0.140974
# 13                      forsen  0.097927  0.029456  0.132461
# 14                 INSCOPE21TV  0.114923  0.027329  0.131365
# 15                       Aydan  0.092403  0.026709  0.116443
# 16              ElcanaldeJoaco  0.150389  0.033945  0.113569
# 17           木棉花官方頻道 (muse_tw)  0.063591  0.044194  0.106186
# 18   Call of Duty (callofduty)  0.180169  0.048804  0.104316
# 19                     Trick2g  0.029041  0.043083  0.102181
# 20                  Diegosaurs  0.060685  0.031759  0.093585
# 21                    mistermv  0.058618  0.036523  0.087594
# 22                      goncho  0.029409  0.048545  0.082931
# 23                    dasMEHDI  0.072794  0.036537  0.080449
# 24                  ClassyBeef  0.042433  0.049830  0.077517
# 25                        aceu  0.154952  0.022491  0.074909
# 26                        wtcN  0.162166  0.021192  0.068471
# 27                     MaTaFe_  0.011553  0.058980  0.067885
# 28                  AustinShow  0.194687  0.027403  0.065904
# 29                    JokerdTV  0.217291  0.034754  0.065694
# 30                       Gorgc  0.110236  0.027306  0.063469
# 31                    Stewie2K  0.050733  0.044877  0.050436
# 32                     natalan  0.057730  0.050429  0.046612
# 33              AdmiralBulldog  0.059442  0.040147  0.039999
# 34                        Kyle  0.019913  0.051944  0.036257
# 35               Trainwreckstv  0.115326  0.021741  0.032874
# 36                    Nadeshot  0.096959  0.031055  0.030585
# 37                      Tyceno  0.045842  0.047516  0.028927
# 38                      Herdyn  0.008374  0.062621  0.027914
# 39                   BRNWOWZK1  0.030921  0.062235  0.027607
# 40                 AnniTheDuck  0.031130  0.051980  0.024997
# 41                      TeePee  0.102781  0.025264  0.022896
# 42                     WARDELL  0.035740  0.046533  0.022095
# 43                     H0llyLP  0.003715  0.073018  0.019397
# 44                     mch_AGG  0.059728  0.049607  0.019294
# 45                   Vinesauce  0.032739  0.046232  0.015443
# 46                 Sweet_Anita  0.074099  0.041225  0.013941
# 47                    PsheroTV  0.012359  0.059292  0.010121
# 48                      Maghla  0.028794  0.047855  0.009113
# 49             KendineMuzisyen  0.129794  0.025478  0.008781
# 50                       Datto  0.047194  0.050357  0.007301
# 51                   Greekgodx  0.100857  0.025948  0.005856
# 52                    Agraelus  0.062418  0.034811  0.005192
# 53                    MarcaoRX  0.029015  0.059714  0.002964
# 54                        WOKE  0.034470  0.049589  0.001497
# 55                       CaMaK  0.002720  0.072035  0.000699
# 56                GhostFreak66  0.054118  0.053419  0.000225
# 57                    Jerma985  0.019393  0.053826 -0.001674
# 58                    Homyatol  0.047607  0.038494 -0.003163
# 59             老皮 (mobilmobil)  0.047755  0.046259 -0.003643
# 60                    Cryaotic  0.002385  0.071399 -0.007397
# 61                       MuTeX  0.011396  0.063282 -0.008925
# 62                   Kandyland  0.026360  0.051165 -0.009214
# 63                  RatedEpicz  0.027059  0.047514 -0.009552
# 64                       Vader  0.057170  0.041727 -0.010704
# 65                      Tourva  0.020182  0.055990 -0.010794
# 66                     Nick28T  0.026990  0.046773 -0.011381
# 67                   innocents  0.030581  0.052192 -0.013258
# 68                    1DrakoNz  0.033966  0.043518 -0.013493
# 69                     Worrun_  0.023734  0.052138 -0.013909
# 70                    Rainbow6  0.199440  0.017763 -0.014042
# 71                RayNarvaezJr  0.001983  0.072704 -0.015119
# 72                       iLame  0.013860  0.060089 -0.015247
# 73                    tarzaned  0.029342  0.045387 -0.016045
# 74                    x6FlipiN  0.024831  0.048934 -0.019061
# 75                   boyMinORu  0.033776  0.045157 -0.019136
# 76                    Pimpeano  0.118889  0.038440 -0.019782
# 77                 RobertoCein  0.053193  0.048001 -0.019902
# 78                    CoconutB  0.004773  0.067994 -0.020455
# 79                      Kotton  0.034528  0.049775 -0.020850
# 80                      scoped  0.135018  0.028831 -0.021399
# 81                     Destiny  0.039631  0.039406 -0.021489
# 82                    Rammus53  0.049166  0.040385 -0.021611
# 83                    HoneyMad  0.041502  0.045145 -0.022049
# 84                    pijack11  0.018499  0.052015 -0.022670
# 85           Zombie_Barricades  0.013793  0.068598 -0.022825
# 86                       maxim  0.020208  0.049517 -0.023039
# 87                        koil  0.017827  0.051895 -0.023201
# 88                        Kiwo  0.017095  0.060644 -0.024103
# 89                 CasinoDaddy  0.029689  0.060925 -0.024805
# 90                    DreadzTV  0.078964  0.038965 -0.025024
# 91                    KabajiOW  0.012869  0.055175 -0.025131
# 92                    Symfuhny  0.174101  0.017503 -0.025743
# 93                        Vovo  0.009438  0.061926 -0.026548
# 94                      RATIRL  0.058835  0.033838 -0.028071
# 95                      flamuu  0.005818  0.065701 -0.028404
# 96                        NymN  0.022237  0.047368 -0.029308
# 97                   skill4ltu  0.006227  0.065204 -0.029846
# 98                      uhSnow  0.008815  0.061361 -0.030700
# 99                       Pengu  0.026657  0.051682 -0.030930
# 100                   ROSHTEIN  0.131110  0.028929 -0.031053
# 101            ProfessorBroman  0.006812  0.067564 -0.031236
# 102                      THump  0.009245  0.060860 -0.031314
# 103                   cellinrj  0.009602  0.060323 -0.032031
# 104                  ItsSlikeR  0.017620  0.051012 -0.033392
# 105                     Pace22  0.013845  0.055761 -0.033517
# 106                      MoMaN  0.019308  0.050238 -0.033774
# 107                     Ko0416  0.019569  0.063426 -0.034067
# 108                김도 (kimdoe)  0.030560  0.053761 -0.034130
# 109               SovietWomble  0.025139  0.050882 -0.034433
# 110                 WeAreTheVR  0.017770  0.051900 -0.035808
# 111               GrandPOObear  0.007305  0.060363 -0.037191
# 112                     Quin69  0.083602  0.033167 -0.038582
# 113                  DougisRaw  0.013123  0.059512 -0.039374
# 114                   Heelmike  0.025481  0.048520 -0.040376
# 115            theRealShooKon3  0.007904  0.066122 -0.040754
# 116                    BikeMan  0.005187  0.069121 -0.040830
# 117                  Alkaizerx  0.003681  0.068704 -0.040876
# 118                       zEkO  0.056365  0.042423 -0.041514
# 119                   Tanxlive  0.009058  0.065007 -0.041917
# 120                 melharucos  0.033292  0.047202 -0.041999
# 121                     adolfz  0.027051  0.049722 -0.042306
# 122                  A_Seagull  0.026670  0.048069 -0.042455
# 123                   Sequisha  0.023728  0.046554 -0.042524
# 124                    Overpow  0.014260  0.057742 -0.043482
# 125                 StaysafeTV  0.019209  0.049056 -0.043549
# 126            BananaSlamJamma  0.002697  0.072540 -0.043857
# 127                      Shotz  0.014352  0.055106 -0.044355
# 128                     trihex  0.009522  0.062665 -0.045352
# 129                 Drjayfisto  0.007907  0.066156 -0.045761
# 130                   Aurateur  0.015760  0.056590 -0.045816
# 131                 嬌兔 (zrush)  0.024357  0.050905 -0.046152
# 132                 Sweatcicle  0.012768  0.058528 -0.046229
# 133                    DieHahn  0.004451  0.066626 -0.046389
# 134                      Limmy  0.010785  0.061424 -0.046933
# 135               TommyKayLIVE  0.003650  0.070842 -0.047427
# 136                   CuteDog_  0.011353  0.067691 -0.047832
# 137                     Criken  0.005497  0.063887 -0.048859
# 138          LAGTVMaximusBlack  0.005647  0.075008 -0.050370
# 139                        cyr  0.011741  0.057093 -0.050639
# 140                     Xposed  0.013044  0.058861 -0.050720
# 141                     buddha  0.016435  0.055809 -0.050788
# 142                  guit88man  0.011769  0.060627 -0.051423
# 143                   singsing  0.013392  0.054906 -0.051615
# 144             小夜夜 (albislol)  0.010640  0.073891 -0.051886
# 145                  roflgator  0.005150  0.066742 -0.052488
# 146                      sips_  0.012901  0.054899 -0.052495
# 147                 SheriffEli  0.004680  0.072162 -0.052546
# 148               FantaBobShow  0.006066  0.064107 -0.052597
# 149                Distortion2  0.013945  0.056469 -0.053057
# 150                   MinosTV_  0.033416  0.042341 -0.053143
# 151            西門夜說 (westdoor)  0.003172  0.072321 -0.053631
# 152                  AlphaCast  0.030523  0.043781 -0.054246
# 153                  Skadoodle  0.033508  0.044212 -0.054647
# 154                       Hype  0.009234  0.059604 -0.054805
# 155                  MANvsGAME  0.002286  0.076214 -0.055171
# 156                      Lasqa  0.007111  0.063946 -0.055927
# 157                 BurkeBlack  0.012923  0.063711 -0.055948
# 158                  gabepeixe  0.003247  0.069804 -0.056338
# 159                    LobosJr  0.005081  0.065857 -0.056835
# 160              Crocodyle_lol  0.006316  0.061487 -0.056971
# 161                     chowh1  0.008453  0.062084 -0.057548
# 162                      B0aty  0.026215  0.047704 -0.058041
# 163                      AkTep  0.003905  0.066330 -0.058219
# 164                    JonBams  0.004497  0.067854 -0.058249
# 165           OfficialAndyPyro  0.017682  0.062037 -0.058390
# 166                     CrReaM  0.004455  0.073896 -0.058977
# 167                    GTimeTV  0.023170  0.051242 -0.059733
# 168                   Surefour  0.003672  0.070455 -0.059882
# 169                Frankkaster  0.070856  0.040271 -0.060751
# 170               ALOHADANCETV  0.027735  0.047637 -0.060776
# 171              BarbarousKing  0.017768  0.054959 -0.060980
# 172                OuterHeaven  0.001529  0.078306 -0.061592
# 173              超負荷 (sam1268)  0.012741  0.065338 -0.062175
# 174                 RoyalPhunk  0.010556  0.058387 -0.062397
# 175                      mang0  0.012384  0.058536 -0.062424
# 176                 mandiocaa1  0.009992  0.069725 -0.063220
# 177              Vargskelethor  0.005887  0.066867 -0.063251
# 178                   Tanovich  0.021558  0.055332 -0.063357
# 179                   ANGRYPUG  0.014700  0.057155 -0.063934
# 180                    Grimmmz  0.021193  0.052246 -0.064541
# 181                      PENTA  0.007199  0.063126 -0.065023
# 182                    HeyarTV  0.005048  0.076858 -0.065675
# 183                Reborn_Live  0.198325  0.024587 -0.066087
# 184                Ezekiel_III  0.006224  0.068620 -0.066556
# 185                      Mendo  0.025114  0.047163 -0.066783
# 186                 Krayn_Live  0.004461  0.072687 -0.067191
# 187                  akagreenn  0.015400  0.056276 -0.067482
# 188                      BreaK  0.003894  0.068435 -0.068226
# 189                    Arteezy  0.096064  0.049452 -0.069014
# 190                      dizzy  0.016217  0.054800 -0.069149
# 191              龜狗 (gueigotv)  0.006773  0.064321 -0.069303
# 192                    Broeki1  0.007045  0.064017 -0.069315
# 193          AvoidingThePuddle  0.014560  0.054935 -0.069361
# 194                 foggedftw2  0.008714  0.061208 -0.069441
# 195              The_Happy_Hob  0.008935  0.060358 -0.069842
# 196                  Peereira7  0.047119  0.044155 -0.070721
# 197                   Spaceboy  0.003890  0.069564 -0.071810
# 198                   EFEUYGAC  0.039544  0.048759 -0.073928
# 199                      Dyrus  0.005146  0.071233 -0.076777

# %% [markdown]
# ### IV- Computational Time Comparaison

# %% [markdown]
# Below are the execution times (in seconds) for different Multi-Criteria Decision-Making (MCDM) methods across varying problem sizes.
# The analysis compares **WSM**, **WPM**, **WASPAS**, **TOPSIS**, and **PROMETHEE** for up to **10,000 alternatives** and **500 criteria** for further study purposes.

# %%
# --- Core Functions ---
def generate_random_matrix(n, m):
    """Generates a random decision matrix of shape (n, m)."""
    return np.random.rand(n, m)

def compute_wsm_score(matrix, weights):
    """Computes WSM scores."""
    return np.sum(matrix * weights, axis=1)

def compute_wpm_score(matrix, weights):
    """Computes WPM scores."""
    return np.prod(matrix ** weights, axis=1)

def compute_wasspass_score(wsm_scores, wpm_scores, lambda_value=0.5):
    """Computes WASPAS scores."""
    return lambda_value * wsm_scores + (1 - lambda_value) * wpm_scores

def compute_topsis(matrix, weights):
    """Computes TOPSIS scores."""
    X_norm = matrix / np.linalg.norm(matrix, axis=0)
    X_weighted = X_norm * weights
    ideal_solution = np.max(X_weighted, axis=0)
    anti_ideal_solution = np.min(X_weighted, axis=0)
    dist_ideal = np.sqrt(np.sum((X_weighted - ideal_solution) ** 2, axis=1))
    dist_anti_ideal = np.sqrt(np.sum((X_weighted - anti_ideal_solution) ** 2, axis=1))
    return dist_anti_ideal / (dist_ideal + dist_anti_ideal)

def compute_promethee(matrix, weights):
    """Computes PROMETHEE scores (simplified version)."""
    n, m = matrix.shape
    normalized_matrix = (matrix - np.min(matrix, axis=0)) / (np.max(matrix, axis=0) - np.min(matrix, axis=0))
    pairwise_diff = normalized_matrix[:, np.newaxis, :] - normalized_matrix[np.newaxis, :, :]
    preference_matrix = np.maximum(pairwise_diff, 0)
    weighted_preference = preference_matrix * weights
    priority_matrix = np.sum(weighted_preference, axis=2)
    phi_plus = np.mean(priority_matrix, axis=1)
    phi_minus = np.mean(priority_matrix, axis=0)
    return phi_plus - phi_minus  # Net flow scores

# --- Benchmark Settings ---
problem_sizes = [
    (50, 10), (100, 10), 
    (200, 20), (500, 20), 
    (1000, 50), (2000, 100), 
    (5000, 200), (10000, 500)
]

# --- Performance Testing ---
results = []
for n, m in problem_sizes:
    print(f"Processing {n} alternatives and {m} criteria...")
    matrix = generate_random_matrix(n, m)
    weights = np.random.rand(m)
    weights /= np.sum(weights)  # Normalize weights

    # Time WSM
    start = time.time()
    _ = compute_wsm_score(matrix, weights)
    wsm_time = time.time() - start

    # Time WPM
    start = time.time()
    _ = compute_wpm_score(matrix, weights)
    wpm_time = time.time() - start

    # Time WASPAS
    start = time.time()
    wsm = compute_wsm_score(matrix, weights)
    wpm = compute_wpm_score(matrix, weights)
    _ = compute_wasspass_score(wsm, wpm)
    wasspass_time = time.time() - start

    # Time TOPSIS
    start = time.time()
    _ = compute_topsis(matrix, weights)
    topsis_time = time.time() - start

    # Time PROMETHEE (skip for large n)
    promethee_time = np.nan
    if n <= 2000:
        start = time.time()
        _ = compute_promethee(matrix, weights)
        promethee_time = time.time() - start

    results.append([n, m, wsm_time, wpm_time, wasspass_time, topsis_time, promethee_time])

# --- Results ---
df_results = pd.DataFrame(results, columns=[
    "Alternatives", "Criteria", 
    "WSM Time", "WPM Time", 
    "WASSPAS Time", "TOPSIS Time", 
    "PROMETHEE Time"
])
print(df_results)
# Out:
# Processing 50 alternatives and 10 criteria...
# Processing 100 alternatives and 10 criteria...
# Processing 200 alternatives and 20 criteria...
# Processing 500 alternatives and 20 criteria...
# Processing 1000 alternatives and 50 criteria...
# Processing 2000 alternatives and 100 criteria...
# Processing 5000 alternatives and 200 criteria...
# Processing 10000 alternatives and 500 criteria...
#    Alternatives  Criteria  WSM Time  WPM Time  WASSPAS Time  TOPSIS Time  PROMETHEE Time
# 0            50        10  0.000000  0.000000      0.000000     0.000000        0.000515
# 1           100        10  0.000529  0.000000      0.000000     0.000000        0.002111
# 2           200        20  0.000000  0.000000      0.000566     0.000000        0.013589
# 3           500        20  0.000000  0.000527      0.000000     0.000555        0.059898
# 4          1000        50  0.000520  0.001026      0.001030     0.000509        0.527261
# 5          2000       100  0.000520  0.005786      0.009140     0.006382        4.445998
# 6          5000       200  0.006826  0.034795      0.035407     0.029630             NaN
# 7         10000       500  0.021613  0.195250      0.162303     0.148792             NaN
